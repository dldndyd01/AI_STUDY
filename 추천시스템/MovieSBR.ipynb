# %%
import datetime as dt
from pathlib import Path
import os

import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data_path = Path(os.getenv('HOME')+'/aiffel/yoochoose/data') 
train_path = data_path / 'ratings.dat'

def load_data(data_path: Path, nrows=None):
    data = pd.read_csv(data_path, sep='::', header=None, usecols=[0, 1, 2, 3], dtype={0: np.int32, 1: np.int32, 2: np.int32}, nrows=nrows)
    data.columns = ['UserId', 'ItemId', 'Rating', 'Time']
    return data

data = load_data(train_path, None)
data.sort_values(['UserId', 'Time'], inplace=True)  # data를 id와 시간 순서로 정렬해줍니다.
data
# Out:
#          UserId  ItemId  Rating       Time
# 31            1    3186       4  978300019
# 22            1    1270       5  978300055
# 27            1    1721       4  978300055
# 37            1    1022       5  978300055
# 24            1    2340       3  978300103
# ...         ...     ...     ...        ...
# 1000019    6040    2917       4  997454429
# 999988     6040    1921       4  997454464
# 1000172    6040    1784       3  997454464
# 1000167    6040     161       3  997454486
# 1000042    6040    1221       4  998315055
#
# [1000209 rows x 4 columns]

# %%
data['UserId'].nunique(), data['ItemId'].nunique()
# Out:
# (6040, 3706)

# %% [markdown]
# 유저 6040명, 아이템 3706개

# %%
date_modify = list(data["Time"])
date_modify
# Out:
# [978300019,
#  978300055,
#  978300055,
#  978300055,
#  978300103,
#  978300172,
#  978300275,
#  978300719,
#  978300719,
#  978300760,
#  978300760,
#  978300760,
#  978301368,
#  978301398,
#  978301570,
#  978301590,
#  978301619,
#  978301713,
#  978301752,
#  978301753,
#  978301753,
#  978301777,
#  978301777,
#  978301777,
#  978301953,
#  978301968,
#  978302039,
#  978302039,
#  978302091,
#  978302091,
#  978302109,
#  978302124,
#  978302149,
#  978302174,
#  978302188,
#  978302205,
#  978302205,
#  978302268,
#  978302268,
#  978302281,
#  978824139,
#  978824195,
#  978824268,
#  978824268,
#  978824268,
#  978824268,
#  978824268,
#  978824291,
#  978824291,
#  978824291,
#  978824330,
#  978824330,
#  978824351,
#  978298124,
#  978298151,
#  978298151,
#  978298196,
#  978298261,
#  978298372,
#  978298391,
#  978298413,
#  978298413,
#  978298434,
#  978298434,
#  978298458,
#  978298458,
#  978298478,
#  978298517,
#  978298517,
#  978298542,
#  978298542,
#  978298542,
#  978298580,
#  978298600,
#  978298625,
#  978298625,
#  978298625,
#  978298652,
#  978298652,
#  978298673,
#  978298709,
#  978298730,
#  978298750,
#  978298775,
#  978298775,
#  978298813,
#  978298813,
#  978298813,
#  978298814,
#  978298814,
#  978298814,
#  978298841,
#  978298841,
#  978298841,
#  978298881,
#  978298881,
#  978298905,
#  978298905,
#  978298924,
#  978298958,
#  978298958,
#  978298958,
#  978299000,
#  978299026,
#  978299046,
#  978299083,
#  978299120,
#  978299120,
#  978299143,
#  978299173,
#  978299200,
#  978299200,
#  978299220,
#  978299250,
#  978299269,
#  978299297,
#  978299297,
#  978299297,
#  978299321,
#  978299351,
#  978299351,
#  978299386,
#  978299418,
#  978299418,
#  978299418,
#  978299535,
#  978299620,
#  978299620,
#  978299641,
#  978299666,
#  978299666,
#  978299686,
#  978299712,
#  978299712,
#  978299712,
#  978299773,
#  978299773,
#  978299773,
#  978299773,
#  978299809,
#  978299809,
#  978299809,
#  978299809,
#  978299809,
#  978299809,
#  978299839,
#  978299839,
#  978299839,
#  978299839,
#  978299839,
#  978299861,
#  978299861,
#  978299889,
#  978299889,
#  978299913,
#  978299913,
#  978299941,
#  978299941,
#  978299941,
#  978299966,
#  978299966,
#  978299966,
#  978300002,
#  978300002,
#  978300002,
#  978300002,
#  978300002,
#  978300002,
#  978300025,
#  978300025,
#  978300051,
#  978300051,
#  978300073,
#  978300100,
#  978300100,
#  978300123,
#  978300123,
#  978300143,
#  978300174,
#  978300174,
#  978300174,
#  978300174,
#  978297018,
#  978297039,
#  978297068,
#  978297068,
#  978297095,
#  978297095,
#  978297396,
#  978297419,
#  978297419,
#  978297419,
#  978297439,
#  978297512,
#  978297539,
#  978297539,
#  978297570,
#  978297570,
#  978297570,
#  978297600,
#  978297600,
#  978297600,
#  978297663,
#  978297663,
#  978297690,
#  978297710,
#  978297757,
#  978297757,
#  978297757,
#  978297777,
#  978297777,
#  978297805,
#  978297837,
#  978297837,
#  978297867,
#  978297867,
#  978298079,
#  978298103,
#  978298147,
#  978298147,
#  978298147,
#  978298166,
#  978298201,
#  978298231,
#  978298296,
#  978298296,
#  978298316,
#  978298430,
#  978298430,
#  978298459,
#  978298486,
#  978298486,
#  978298504,
#  978293924,
#  978293964,
#  978294008,
#  978294008,
#  978294008,
#  978294199,
#  978294199,
#  978294199,
#  978294199,
#  978294230,
#  978294230,
#  978294230,
#  978294230,
#  978294230,
#  978294260,
#  978294260,
#  978294260,
#  978294260,
#  978294282,
#  978294282,
#  978294282,
#  978241072,
#  978241072,
#  978241072,
#  978241112,
#  978241112,
#  978241390,
#  978241390,
#  978241390,
#  978241434,
#  978241434,
#  978241556,
#  978241981,
#  978241981,
#  978241981,
#  978241981,
#  978242016,
#  978242080,
#  978242080,
#  978242323,
#  978242323,
#  978242323,
#  978242541,
#  978242541,
#  978242541,
#  978242607,
#  978242607,
#  978242607,
#  978242607,
#  978242640,
#  978242679,
#  978242740,
#  978242788,
#  978242788,
#  978242847,
#  978242934,
#  978242934,
#  978242934,
#  978242977,
#  978242977,
#  978242977,
#  978243054,
#  978243054,
#  978243054,
#  978243085,
#  978243085,
#  978243085,
#  978243121,
#  978243121,
#  978243121,
#  978243170,
#  978243170,
#  978243803,
#  978243803,
#  978243869,
#  978243896,
#  978243896,
#  978243937,
#  978244001,
#  978244001,
#  978244025,
#  978244053,
#  978244114,
#  978244114,
#  978244177,
#  978244177,
#  978244177,
#  978244177,
#  978244177,
#  978244205,
#  978244205,
#  978244205,
#  978244493,
#  978244493,
#  978244493,
#  978244493,
#  978244493,
#  978244517,
#  978244540,
#  978244540,
#  978244540,
#  978244540,
#  978244568,
#  978244568,
#  978244568,
#  978244603,
#  978244603,
#  978244603,
#  978244603,
#  978244624,
#  978244624,
#  978244667,
#  978244667,
#  978244692,
#  978244759,
#  978244759,
#  978244759,
#  978244808,
#  978244808,
#  978244808,
#  978244808,
#  978244830,
#  978244852,
#  978244852,
#  978244893,
#  978244893,
#  978244962,
#  978244962,
#  978244962,
#  978244962,
#  978245037,
#  978245037,
#  978245037,
#  978245065,
#  978245065,
#  978245065,
#  978245065,
#  978245314,
#  978245314,
#  978245314,
#  978245314,
#  978245314,
#  978245334,
#  978245334,
#  978245334,
#  978245422,
#  978245422,
#  978245445,
#  978245445,
#  978245487,
#  978245513,
#  978245513,
#  978245548,
#  978245568,
#  978245568,
#  978245568,
#  978245645,
#  978245645,
#  978245645,
#  978245645,
#  978245645,
#  978245663,
#  978245687,
#  978245695,
#  978245708,
#  978245740,
#  978245740,
#  978245763,
#  978245763,
#  978245763,
#  978245763,
#  978245790,
#  978245790,
#  978245829,
#  978245829,
#  978245829,
#  978245829,
#  978245863,
#  978245863,
#  978245891,
#  978245891,
#  978245891,
#  978245891,
#  978245916,
#  978245916,
#  978245916,
#  978245916,
#  978245916,
#  978245931,
#  978245948,
#  978245948,
#  978245966,
#  978245999,
#  978245999,
#  978245999,
#  978246033,
#  978246033,
#  978246108,
#  978246108,
#  978246108,
#  978246162,
#  978246162,
#  978246162,
#  978246162,
#  978246426,
#  978246426,
#  978246450,
#  978246450,
#  978246479,
#  978246479,
#  978246479,
#  978246504,
#  978246504,
#  978246528,
#  978246555,
#  978246576,
#  978246576,
#  978246576,
#  978246585,
#  978236075,
#  978236122,
#  978236122,
#  978236219,
#  978236219,
#  978236219,
#  978236383,
#  978236383,
#  978236383,
#  978236519,
#  978236519,
#  978236567,
#  978236567,
#  978236567,
#  978236567,
#  978236612,
#  978236612,
#  978236670,
#  978236670,
#  978236670,
#  978236670,
#  978236670,
#  978236719,
#  978236771,
#  978236809,
#  978236809,
#  978236876,
#  978236876,
#  978236975,
#  978236975,
#  978237008,
#  978237034,
#  978237232,
#  978237273,
#  978237379,
#  978237444,
#  978237444,
#  978237511,
#  978237511,
#  978237570,
#  978237570,
#  978237570,
#  978237570,
#  978237570,
#  978237691,
#  978237691,
#  978237767,
#  978237767,
#  978237767,
#  978237767,
#  978237767,
#  978237813,
#  978237813,
#  978237813,
#  978237909,
#  978237909,
#  978237909,
#  978238036,
#  978238036,
#  978238036,
#  978238036,
#  978238195,
#  978238195,
#  978238230,
#  978238230,
#  978238256,
#  978238288,
#  978238371,
#  978238851,
#  978238948,
#  978239019,
#  978234581,
#  978234607,
#  978234632,
#  978234632,
#  978234659,
#  978234737,
#  978234737,
#  978234737,
#  978234737,
#  978234737,
#  978234786,
#  978234786,
#  978234786,
#  978234786,
#  978234786,
#  978234786,
#  978234810,
#  978234810,
#  978234842,
#  978234842,
#  978234842,
#  978234842,
#  978234842,
#  978234874,
#  978234874,
#  978234874,
#  978234874,
#  978234874,
#  978234874,
#  978234874,
#  978234898,
#  978228789,
#  978228832,
#  978228882,
#  978228882,
#  978228960,
#  978228960,
#  978229138,
#  978229138,
#  978229138,
#  978229138,
#  978229138,
#  978229138,
#  978229172,
#  978229172,
#  978229172,
#  978229204,
#  978229204,
#  978229204,
#  978229204,
#  978229246,
#  978229246,
#  978229293,
#  978229293,
#  978229293,
#  978229293,
#  978229347,
#  978229347,
#  978229347,
#  978229347,
#  978229347,
#  978229391,
#  978229391,
#  978229477,
#  978229524,
#  978229524,
#  978229571,
#  978229571,
#  978229571,
#  978229614,
#  978229614,
#  978229614,
#  978229702,
#  978229702,
#  978229702,
#  978229817,
#  978229817,
#  978229857,
#  978229857,
#  978229857,
#  978229900,
#  978229900,
#  978229957,
#  978229979,
#  978230013,
#  978230013,
#  978230013,
#  978230052,
#  978230052,
#  978230095,
#  978230120,
#  978230152,
#  978230184,
#  978230184,
#  978230227,
#  978230248,
#  978230248,
#  978230286,
#  978230286,
#  978230356,
#  978230391,
#  978230391,
#  978230391,
#  978230391,
#  978230435,
#  978230435,
#  978230483,
#  978230483,
#  978230550,
#  978230550,
#  978230577,
#  978230611,
#  978230611,
#  978230611,
#  978230649,
#  978230666,
#  978230687,
#  978230756,
#  978230800,
#  978230800,
#  978230852,
#  978230852,
#  978230852,
#  978230886,
#  978230886,
#  978230943,
#  978230943,
#  978230943,
#  978230943,
#  978230943,
#  978230966,
#  978230966,
#  978231031,
#  978231031,
#  978231121,
#  978231121,
#  978231150,
#  978231173,
#  978231173,
#  978231252,
#  978231429,
#  978231493,
#  978231571,
#  978231592,
#  978231614,
#  978231637,
#  978231659,
#  978231687,
#  978231802,
#  978231802,
#  978231802,
#  978231890,
#  978231890,
#  978231982,
#  978231982,
#  978232012,
#  978232056,
#  978232056,
#  978232056,
#  978232056,
#  978232203,
#  978232203,
#  978232231,
#  978232754,
#  978232754,
#  978233462,
#  978233462,
#  978233496,
#  978233526,
#  978247143,
#  978224859,
#  978224859,
#  978224879,
#  978224893,
#  978224908,
#  978224908,
#  978225153,
#  978225177,
#  978225303,
#  978225303,
#  978225314,
#  978225314,
#  978225333,
#  978225333,
#  978225333,
#  978225401,
#  978225429,
#  978225429,
#  978225489,
#  978225570,
#  978225570,
#  978225581,
#  978225613,
#  978225671,
#  978225686,
#  978225709,
#  978225718,
#  978225730,
#  978225746,
#  978225758,
#  978225778,
#  978225827,
#  978225883,
#  978225898,
#  978225898,
#  978225898,
#  978225908,
#  978225924,
#  978225924,
#  978225952,
#  978225952,
#  978225952,
#  978225968,
#  978225968,
#  978225984,
#  978225984,
#  978225984,
#  978226006,
#  978226006,
#  978226023,
#  978226041,
#  978226041,
#  978226041,
#  978226054,
#  978226066,
#  978226066,
#  978226081,
#  978226081,
#  978226093,
#  978226109,
#  978226109,
#  978226123,
#  978226123,
#  978226150,
#  978226150,
#  978226150,
#  978226165,
#  978226165,
#  978226165,
#  978226197,
#  978226207,
#  978226216,
#  978226233,
#  978226248,
#  978226248,
#  978226248,
#  978226261,
#  978226261,
#  978226261,
#  978226277,
#  978226291,
#  978226291,
#  978226302,
#  978226315,
#  978226328,
#  978226343,
#  978226368,
#  978226434,
#  978226448,
#  978226448,
#  978226463,
#  978226473,
#  978226495,
#  978226495,
#  978226564,
#  978226564,
#  978226564,
#  978226580,
#  978226599,
#  978226599,
#  978226619,
#  978226644,
#  978226665,
#  978226665,
#  978226678,
#  978226678,
#  978224375,
#  978224375,
#  978224375,
#  978224400,
#  978224400,
#  978224549,
#  978224549,
#  978224549,
#  978224549,
#  978224627,
#  978224675,
#  978224705,
#  978224705,
#  978224705,
#  978224749,
#  978224779,
#  978224779,
#  978224779,
#  978224821,
#  978224925,
#  978225033,
#  978225050,
#  978225070,
#  978225428,
#  978225456,
#  978225541,
#  978225541,
#  978225561,
#  978225599,
#  978225630,
#  978225630,
#  978225630,
#  978225682,
#  978225682,
#  978225682,
#  978225708,
#  978225735,
#  978225735,
#  978225735,
#  978225759,
#  978225779,
#  978225800,
#  978225800,
#  978225824,
#  978225824,
#  978225853,
#  978225853,
#  978225900,
#  978225900,
#  978225900,
#  978225922,
#  978225922,
#  978225922,
#  978225952,
#  978225952,
#  978225952,
#  978225997,
#  978225997,
#  978226026,
#  978226068,
#  978226103,
#  978226103,
#  978226128,
#  978226147,
#  978226165,
#  978226165,
#  978226186,
#  978226212,
#  978226212,
#  978226212,
#  978226231,
#  978226254,
#  978226287,
#  978226287,
#  978226287,
#  978226319,
#  978226319,
#  978226319,
#  978226349,
#  978226349,
#  978226378,
#  978226401,
#  978226402,
#  978226425,
#  978226443,
#  978226474,
#  978226474,
#  978226500,
#  978226500,
#  978226500,
#  978226500,
#  978226546,
#  978226572,
#  978226698,
#  978226698,
#  978226739,
#  978226739,
#  978226766,
#  978226805,
#  978226805,
#  978226805,
#  978226833,
#  978226866,
#  978226866,
#  978226866,
#  978226866,
#  978226866,
#  978226896,
#  978226896,
#  978226913,
#  978226951,
#  978226968,
#  978227003,
#  978227003,
#  978227003,
#  978227028,
#  978227029,
#  978227051,
#  978227051,
#  978227087,
#  978227105,
#  978227125,
#  978227143,
#  978227166,
#  978227166,
#  978227188,
#  978227188,
#  978227215,
#  978227215,
#  978227239,
#  978227239,
#  978227263,
#  978227263,
#  978227300,
#  978227300,
#  978227300,
#  978227300,
#  978227317,
#  978227336,
#  978227379,
#  978227425,
#  978227442,
#  978227462,
#  978227481,
#  978227503,
#  978227503,
#  978227529,
#  978227551,
#  978227551,
#  978227574,
#  978227625,
#  978227625,
#  978227625,
#  978227646,
#  978227646,
#  978227669,
#  978227669,
#  978227669,
#  978227696,
#  978227696,
#  978227763,
#  978227763,
#  978227807,
#  978227842,
#  978227848,
#  978227871,
#  978227871,
#  978227912,
#  978227934,
#  978227961,
#  978227993,
#  978228053,
#  978228053,
#  978228074,
#  978228074,
#  978228118,
#  978228118,
#  978228153,
#  978228153,
#  978228174,
#  978228174,
#  978228212,
#  978228212,
#  978228212,
#  978228288,
#  978228288,
#  978228307,
#  978228307,
#  978228364,
#  978228364,
#  978228408,
#  978228408,
#  978228428,
#  978228451,
#  978228451,
#  978228525,
#  978228546,
#  978228575,
#  978228601,
#  978228601,
#  978228601,
#  ...]

# %%
import datetime
from tqdm import tqdm
a = []
dt1 = datetime.datetime(1970, 1, 1)
for i in tqdm(date_modify):
    d = datetime.timedelta(seconds=i)
    a.append(dt1 + d)
a
# Out:
# 100%|██████████| 1000209/1000209 [00:00<00:00, 1015962.54it/s]
# [datetime.datetime(2000, 12, 31, 22, 0, 19),
#  datetime.datetime(2000, 12, 31, 22, 0, 55),
#  datetime.datetime(2000, 12, 31, 22, 0, 55),
#  datetime.datetime(2000, 12, 31, 22, 0, 55),
#  datetime.datetime(2000, 12, 31, 22, 1, 43),
#  datetime.datetime(2000, 12, 31, 22, 2, 52),
#  datetime.datetime(2000, 12, 31, 22, 4, 35),
#  datetime.datetime(2000, 12, 31, 22, 11, 59),
#  datetime.datetime(2000, 12, 31, 22, 11, 59),
#  datetime.datetime(2000, 12, 31, 22, 12, 40),
#  datetime.datetime(2000, 12, 31, 22, 12, 40),
#  datetime.datetime(2000, 12, 31, 22, 12, 40),
#  datetime.datetime(2000, 12, 31, 22, 22, 48),
#  datetime.datetime(2000, 12, 31, 22, 23, 18),
#  datetime.datetime(2000, 12, 31, 22, 26, 10),
#  datetime.datetime(2000, 12, 31, 22, 26, 30),
#  datetime.datetime(2000, 12, 31, 22, 26, 59),
#  datetime.datetime(2000, 12, 31, 22, 28, 33),
#  datetime.datetime(2000, 12, 31, 22, 29, 12),
#  datetime.datetime(2000, 12, 31, 22, 29, 13),
#  datetime.datetime(2000, 12, 31, 22, 29, 13),
#  datetime.datetime(2000, 12, 31, 22, 29, 37),
#  datetime.datetime(2000, 12, 31, 22, 29, 37),
#  datetime.datetime(2000, 12, 31, 22, 29, 37),
#  datetime.datetime(2000, 12, 31, 22, 32, 33),
#  datetime.datetime(2000, 12, 31, 22, 32, 48),
#  datetime.datetime(2000, 12, 31, 22, 33, 59),
#  datetime.datetime(2000, 12, 31, 22, 33, 59),
#  datetime.datetime(2000, 12, 31, 22, 34, 51),
#  datetime.datetime(2000, 12, 31, 22, 34, 51),
#  datetime.datetime(2000, 12, 31, 22, 35, 9),
#  datetime.datetime(2000, 12, 31, 22, 35, 24),
#  datetime.datetime(2000, 12, 31, 22, 35, 49),
#  datetime.datetime(2000, 12, 31, 22, 36, 14),
#  datetime.datetime(2000, 12, 31, 22, 36, 28),
#  datetime.datetime(2000, 12, 31, 22, 36, 45),
#  datetime.datetime(2000, 12, 31, 22, 36, 45),
#  datetime.datetime(2000, 12, 31, 22, 37, 48),
#  datetime.datetime(2000, 12, 31, 22, 37, 48),
#  datetime.datetime(2000, 12, 31, 22, 38, 1),
#  datetime.datetime(2001, 1, 6, 23, 35, 39),
#  datetime.datetime(2001, 1, 6, 23, 36, 35),
#  datetime.datetime(2001, 1, 6, 23, 37, 48),
#  datetime.datetime(2001, 1, 6, 23, 37, 48),
#  datetime.datetime(2001, 1, 6, 23, 37, 48),
#  datetime.datetime(2001, 1, 6, 23, 37, 48),
#  datetime.datetime(2001, 1, 6, 23, 37, 48),
#  datetime.datetime(2001, 1, 6, 23, 38, 11),
#  datetime.datetime(2001, 1, 6, 23, 38, 11),
#  datetime.datetime(2001, 1, 6, 23, 38, 11),
#  datetime.datetime(2001, 1, 6, 23, 38, 50),
#  datetime.datetime(2001, 1, 6, 23, 38, 50),
#  datetime.datetime(2001, 1, 6, 23, 39, 11),
#  datetime.datetime(2000, 12, 31, 21, 28, 44),
#  datetime.datetime(2000, 12, 31, 21, 29, 11),
#  datetime.datetime(2000, 12, 31, 21, 29, 11),
#  datetime.datetime(2000, 12, 31, 21, 29, 56),
#  datetime.datetime(2000, 12, 31, 21, 31, 1),
#  datetime.datetime(2000, 12, 31, 21, 32, 52),
#  datetime.datetime(2000, 12, 31, 21, 33, 11),
#  datetime.datetime(2000, 12, 31, 21, 33, 33),
#  datetime.datetime(2000, 12, 31, 21, 33, 33),
#  datetime.datetime(2000, 12, 31, 21, 33, 54),
#  datetime.datetime(2000, 12, 31, 21, 33, 54),
#  datetime.datetime(2000, 12, 31, 21, 34, 18),
#  datetime.datetime(2000, 12, 31, 21, 34, 18),
#  datetime.datetime(2000, 12, 31, 21, 34, 38),
#  datetime.datetime(2000, 12, 31, 21, 35, 17),
#  datetime.datetime(2000, 12, 31, 21, 35, 17),
#  datetime.datetime(2000, 12, 31, 21, 35, 42),
#  datetime.datetime(2000, 12, 31, 21, 35, 42),
#  datetime.datetime(2000, 12, 31, 21, 35, 42),
#  datetime.datetime(2000, 12, 31, 21, 36, 20),
#  datetime.datetime(2000, 12, 31, 21, 36, 40),
#  datetime.datetime(2000, 12, 31, 21, 37, 5),
#  datetime.datetime(2000, 12, 31, 21, 37, 5),
#  datetime.datetime(2000, 12, 31, 21, 37, 5),
#  datetime.datetime(2000, 12, 31, 21, 37, 32),
#  datetime.datetime(2000, 12, 31, 21, 37, 32),
#  datetime.datetime(2000, 12, 31, 21, 37, 53),
#  datetime.datetime(2000, 12, 31, 21, 38, 29),
#  datetime.datetime(2000, 12, 31, 21, 38, 50),
#  datetime.datetime(2000, 12, 31, 21, 39, 10),
#  datetime.datetime(2000, 12, 31, 21, 39, 35),
#  datetime.datetime(2000, 12, 31, 21, 39, 35),
#  datetime.datetime(2000, 12, 31, 21, 40, 13),
#  datetime.datetime(2000, 12, 31, 21, 40, 13),
#  datetime.datetime(2000, 12, 31, 21, 40, 13),
#  datetime.datetime(2000, 12, 31, 21, 40, 14),
#  datetime.datetime(2000, 12, 31, 21, 40, 14),
#  datetime.datetime(2000, 12, 31, 21, 40, 14),
#  datetime.datetime(2000, 12, 31, 21, 40, 41),
#  datetime.datetime(2000, 12, 31, 21, 40, 41),
#  datetime.datetime(2000, 12, 31, 21, 40, 41),
#  datetime.datetime(2000, 12, 31, 21, 41, 21),
#  datetime.datetime(2000, 12, 31, 21, 41, 21),
#  datetime.datetime(2000, 12, 31, 21, 41, 45),
#  datetime.datetime(2000, 12, 31, 21, 41, 45),
#  datetime.datetime(2000, 12, 31, 21, 42, 4),
#  datetime.datetime(2000, 12, 31, 21, 42, 38),
#  datetime.datetime(2000, 12, 31, 21, 42, 38),
#  datetime.datetime(2000, 12, 31, 21, 42, 38),
#  datetime.datetime(2000, 12, 31, 21, 43, 20),
#  datetime.datetime(2000, 12, 31, 21, 43, 46),
#  datetime.datetime(2000, 12, 31, 21, 44, 6),
#  datetime.datetime(2000, 12, 31, 21, 44, 43),
#  datetime.datetime(2000, 12, 31, 21, 45, 20),
#  datetime.datetime(2000, 12, 31, 21, 45, 20),
#  datetime.datetime(2000, 12, 31, 21, 45, 43),
#  datetime.datetime(2000, 12, 31, 21, 46, 13),
#  datetime.datetime(2000, 12, 31, 21, 46, 40),
#  datetime.datetime(2000, 12, 31, 21, 46, 40),
#  datetime.datetime(2000, 12, 31, 21, 47),
#  datetime.datetime(2000, 12, 31, 21, 47, 30),
#  datetime.datetime(2000, 12, 31, 21, 47, 49),
#  datetime.datetime(2000, 12, 31, 21, 48, 17),
#  datetime.datetime(2000, 12, 31, 21, 48, 17),
#  datetime.datetime(2000, 12, 31, 21, 48, 17),
#  datetime.datetime(2000, 12, 31, 21, 48, 41),
#  datetime.datetime(2000, 12, 31, 21, 49, 11),
#  datetime.datetime(2000, 12, 31, 21, 49, 11),
#  datetime.datetime(2000, 12, 31, 21, 49, 46),
#  datetime.datetime(2000, 12, 31, 21, 50, 18),
#  datetime.datetime(2000, 12, 31, 21, 50, 18),
#  datetime.datetime(2000, 12, 31, 21, 50, 18),
#  datetime.datetime(2000, 12, 31, 21, 52, 15),
#  datetime.datetime(2000, 12, 31, 21, 53, 40),
#  datetime.datetime(2000, 12, 31, 21, 53, 40),
#  datetime.datetime(2000, 12, 31, 21, 54, 1),
#  datetime.datetime(2000, 12, 31, 21, 54, 26),
#  datetime.datetime(2000, 12, 31, 21, 54, 26),
#  datetime.datetime(2000, 12, 31, 21, 54, 46),
#  datetime.datetime(2000, 12, 31, 21, 55, 12),
#  datetime.datetime(2000, 12, 31, 21, 55, 12),
#  datetime.datetime(2000, 12, 31, 21, 55, 12),
#  datetime.datetime(2000, 12, 31, 21, 56, 13),
#  datetime.datetime(2000, 12, 31, 21, 56, 13),
#  datetime.datetime(2000, 12, 31, 21, 56, 13),
#  datetime.datetime(2000, 12, 31, 21, 56, 13),
#  datetime.datetime(2000, 12, 31, 21, 56, 49),
#  datetime.datetime(2000, 12, 31, 21, 56, 49),
#  datetime.datetime(2000, 12, 31, 21, 56, 49),
#  datetime.datetime(2000, 12, 31, 21, 56, 49),
#  datetime.datetime(2000, 12, 31, 21, 56, 49),
#  datetime.datetime(2000, 12, 31, 21, 56, 49),
#  datetime.datetime(2000, 12, 31, 21, 57, 19),
#  datetime.datetime(2000, 12, 31, 21, 57, 19),
#  datetime.datetime(2000, 12, 31, 21, 57, 19),
#  datetime.datetime(2000, 12, 31, 21, 57, 19),
#  datetime.datetime(2000, 12, 31, 21, 57, 19),
#  datetime.datetime(2000, 12, 31, 21, 57, 41),
#  datetime.datetime(2000, 12, 31, 21, 57, 41),
#  datetime.datetime(2000, 12, 31, 21, 58, 9),
#  datetime.datetime(2000, 12, 31, 21, 58, 9),
#  datetime.datetime(2000, 12, 31, 21, 58, 33),
#  datetime.datetime(2000, 12, 31, 21, 58, 33),
#  datetime.datetime(2000, 12, 31, 21, 59, 1),
#  datetime.datetime(2000, 12, 31, 21, 59, 1),
#  datetime.datetime(2000, 12, 31, 21, 59, 1),
#  datetime.datetime(2000, 12, 31, 21, 59, 26),
#  datetime.datetime(2000, 12, 31, 21, 59, 26),
#  datetime.datetime(2000, 12, 31, 21, 59, 26),
#  datetime.datetime(2000, 12, 31, 22, 0, 2),
#  datetime.datetime(2000, 12, 31, 22, 0, 2),
#  datetime.datetime(2000, 12, 31, 22, 0, 2),
#  datetime.datetime(2000, 12, 31, 22, 0, 2),
#  datetime.datetime(2000, 12, 31, 22, 0, 2),
#  datetime.datetime(2000, 12, 31, 22, 0, 2),
#  datetime.datetime(2000, 12, 31, 22, 0, 25),
#  datetime.datetime(2000, 12, 31, 22, 0, 25),
#  datetime.datetime(2000, 12, 31, 22, 0, 51),
#  datetime.datetime(2000, 12, 31, 22, 0, 51),
#  datetime.datetime(2000, 12, 31, 22, 1, 13),
#  datetime.datetime(2000, 12, 31, 22, 1, 40),
#  datetime.datetime(2000, 12, 31, 22, 1, 40),
#  datetime.datetime(2000, 12, 31, 22, 2, 3),
#  datetime.datetime(2000, 12, 31, 22, 2, 3),
#  datetime.datetime(2000, 12, 31, 22, 2, 23),
#  datetime.datetime(2000, 12, 31, 22, 2, 54),
#  datetime.datetime(2000, 12, 31, 22, 2, 54),
#  datetime.datetime(2000, 12, 31, 22, 2, 54),
#  datetime.datetime(2000, 12, 31, 22, 2, 54),
#  datetime.datetime(2000, 12, 31, 21, 10, 18),
#  datetime.datetime(2000, 12, 31, 21, 10, 39),
#  datetime.datetime(2000, 12, 31, 21, 11, 8),
#  datetime.datetime(2000, 12, 31, 21, 11, 8),
#  datetime.datetime(2000, 12, 31, 21, 11, 35),
#  datetime.datetime(2000, 12, 31, 21, 11, 35),
#  datetime.datetime(2000, 12, 31, 21, 16, 36),
#  datetime.datetime(2000, 12, 31, 21, 16, 59),
#  datetime.datetime(2000, 12, 31, 21, 16, 59),
#  datetime.datetime(2000, 12, 31, 21, 16, 59),
#  datetime.datetime(2000, 12, 31, 21, 17, 19),
#  datetime.datetime(2000, 12, 31, 21, 18, 32),
#  datetime.datetime(2000, 12, 31, 21, 18, 59),
#  datetime.datetime(2000, 12, 31, 21, 18, 59),
#  datetime.datetime(2000, 12, 31, 21, 19, 30),
#  datetime.datetime(2000, 12, 31, 21, 19, 30),
#  datetime.datetime(2000, 12, 31, 21, 19, 30),
#  datetime.datetime(2000, 12, 31, 21, 20),
#  datetime.datetime(2000, 12, 31, 21, 20),
#  datetime.datetime(2000, 12, 31, 21, 20),
#  datetime.datetime(2000, 12, 31, 21, 21, 3),
#  datetime.datetime(2000, 12, 31, 21, 21, 3),
#  datetime.datetime(2000, 12, 31, 21, 21, 30),
#  datetime.datetime(2000, 12, 31, 21, 21, 50),
#  datetime.datetime(2000, 12, 31, 21, 22, 37),
#  datetime.datetime(2000, 12, 31, 21, 22, 37),
#  datetime.datetime(2000, 12, 31, 21, 22, 37),
#  datetime.datetime(2000, 12, 31, 21, 22, 57),
#  datetime.datetime(2000, 12, 31, 21, 22, 57),
#  datetime.datetime(2000, 12, 31, 21, 23, 25),
#  datetime.datetime(2000, 12, 31, 21, 23, 57),
#  datetime.datetime(2000, 12, 31, 21, 23, 57),
#  datetime.datetime(2000, 12, 31, 21, 24, 27),
#  datetime.datetime(2000, 12, 31, 21, 24, 27),
#  datetime.datetime(2000, 12, 31, 21, 27, 59),
#  datetime.datetime(2000, 12, 31, 21, 28, 23),
#  datetime.datetime(2000, 12, 31, 21, 29, 7),
#  datetime.datetime(2000, 12, 31, 21, 29, 7),
#  datetime.datetime(2000, 12, 31, 21, 29, 7),
#  datetime.datetime(2000, 12, 31, 21, 29, 26),
#  datetime.datetime(2000, 12, 31, 21, 30, 1),
#  datetime.datetime(2000, 12, 31, 21, 30, 31),
#  datetime.datetime(2000, 12, 31, 21, 31, 36),
#  datetime.datetime(2000, 12, 31, 21, 31, 36),
#  datetime.datetime(2000, 12, 31, 21, 31, 56),
#  datetime.datetime(2000, 12, 31, 21, 33, 50),
#  datetime.datetime(2000, 12, 31, 21, 33, 50),
#  datetime.datetime(2000, 12, 31, 21, 34, 19),
#  datetime.datetime(2000, 12, 31, 21, 34, 46),
#  datetime.datetime(2000, 12, 31, 21, 34, 46),
#  datetime.datetime(2000, 12, 31, 21, 35, 4),
#  datetime.datetime(2000, 12, 31, 20, 18, 44),
#  datetime.datetime(2000, 12, 31, 20, 19, 24),
#  datetime.datetime(2000, 12, 31, 20, 20, 8),
#  datetime.datetime(2000, 12, 31, 20, 20, 8),
#  datetime.datetime(2000, 12, 31, 20, 20, 8),
#  datetime.datetime(2000, 12, 31, 20, 23, 19),
#  datetime.datetime(2000, 12, 31, 20, 23, 19),
#  datetime.datetime(2000, 12, 31, 20, 23, 19),
#  datetime.datetime(2000, 12, 31, 20, 23, 19),
#  datetime.datetime(2000, 12, 31, 20, 23, 50),
#  datetime.datetime(2000, 12, 31, 20, 23, 50),
#  datetime.datetime(2000, 12, 31, 20, 23, 50),
#  datetime.datetime(2000, 12, 31, 20, 23, 50),
#  datetime.datetime(2000, 12, 31, 20, 23, 50),
#  datetime.datetime(2000, 12, 31, 20, 24, 20),
#  datetime.datetime(2000, 12, 31, 20, 24, 20),
#  datetime.datetime(2000, 12, 31, 20, 24, 20),
#  datetime.datetime(2000, 12, 31, 20, 24, 20),
#  datetime.datetime(2000, 12, 31, 20, 24, 42),
#  datetime.datetime(2000, 12, 31, 20, 24, 42),
#  datetime.datetime(2000, 12, 31, 20, 24, 42),
#  datetime.datetime(2000, 12, 31, 5, 37, 52),
#  datetime.datetime(2000, 12, 31, 5, 37, 52),
#  datetime.datetime(2000, 12, 31, 5, 37, 52),
#  datetime.datetime(2000, 12, 31, 5, 38, 32),
#  datetime.datetime(2000, 12, 31, 5, 38, 32),
#  datetime.datetime(2000, 12, 31, 5, 43, 10),
#  datetime.datetime(2000, 12, 31, 5, 43, 10),
#  datetime.datetime(2000, 12, 31, 5, 43, 10),
#  datetime.datetime(2000, 12, 31, 5, 43, 54),
#  datetime.datetime(2000, 12, 31, 5, 43, 54),
#  datetime.datetime(2000, 12, 31, 5, 45, 56),
#  datetime.datetime(2000, 12, 31, 5, 53, 1),
#  datetime.datetime(2000, 12, 31, 5, 53, 1),
#  datetime.datetime(2000, 12, 31, 5, 53, 1),
#  datetime.datetime(2000, 12, 31, 5, 53, 1),
#  datetime.datetime(2000, 12, 31, 5, 53, 36),
#  datetime.datetime(2000, 12, 31, 5, 54, 40),
#  datetime.datetime(2000, 12, 31, 5, 54, 40),
#  datetime.datetime(2000, 12, 31, 5, 58, 43),
#  datetime.datetime(2000, 12, 31, 5, 58, 43),
#  datetime.datetime(2000, 12, 31, 5, 58, 43),
#  datetime.datetime(2000, 12, 31, 6, 2, 21),
#  datetime.datetime(2000, 12, 31, 6, 2, 21),
#  datetime.datetime(2000, 12, 31, 6, 2, 21),
#  datetime.datetime(2000, 12, 31, 6, 3, 27),
#  datetime.datetime(2000, 12, 31, 6, 3, 27),
#  datetime.datetime(2000, 12, 31, 6, 3, 27),
#  datetime.datetime(2000, 12, 31, 6, 3, 27),
#  datetime.datetime(2000, 12, 31, 6, 4),
#  datetime.datetime(2000, 12, 31, 6, 4, 39),
#  datetime.datetime(2000, 12, 31, 6, 5, 40),
#  datetime.datetime(2000, 12, 31, 6, 6, 28),
#  datetime.datetime(2000, 12, 31, 6, 6, 28),
#  datetime.datetime(2000, 12, 31, 6, 7, 27),
#  datetime.datetime(2000, 12, 31, 6, 8, 54),
#  datetime.datetime(2000, 12, 31, 6, 8, 54),
#  datetime.datetime(2000, 12, 31, 6, 8, 54),
#  datetime.datetime(2000, 12, 31, 6, 9, 37),
#  datetime.datetime(2000, 12, 31, 6, 9, 37),
#  datetime.datetime(2000, 12, 31, 6, 9, 37),
#  datetime.datetime(2000, 12, 31, 6, 10, 54),
#  datetime.datetime(2000, 12, 31, 6, 10, 54),
#  datetime.datetime(2000, 12, 31, 6, 10, 54),
#  datetime.datetime(2000, 12, 31, 6, 11, 25),
#  datetime.datetime(2000, 12, 31, 6, 11, 25),
#  datetime.datetime(2000, 12, 31, 6, 11, 25),
#  datetime.datetime(2000, 12, 31, 6, 12, 1),
#  datetime.datetime(2000, 12, 31, 6, 12, 1),
#  datetime.datetime(2000, 12, 31, 6, 12, 1),
#  datetime.datetime(2000, 12, 31, 6, 12, 50),
#  datetime.datetime(2000, 12, 31, 6, 12, 50),
#  datetime.datetime(2000, 12, 31, 6, 23, 23),
#  datetime.datetime(2000, 12, 31, 6, 23, 23),
#  datetime.datetime(2000, 12, 31, 6, 24, 29),
#  datetime.datetime(2000, 12, 31, 6, 24, 56),
#  datetime.datetime(2000, 12, 31, 6, 24, 56),
#  datetime.datetime(2000, 12, 31, 6, 25, 37),
#  datetime.datetime(2000, 12, 31, 6, 26, 41),
#  datetime.datetime(2000, 12, 31, 6, 26, 41),
#  datetime.datetime(2000, 12, 31, 6, 27, 5),
#  datetime.datetime(2000, 12, 31, 6, 27, 33),
#  datetime.datetime(2000, 12, 31, 6, 28, 34),
#  datetime.datetime(2000, 12, 31, 6, 28, 34),
#  datetime.datetime(2000, 12, 31, 6, 29, 37),
#  datetime.datetime(2000, 12, 31, 6, 29, 37),
#  datetime.datetime(2000, 12, 31, 6, 29, 37),
#  datetime.datetime(2000, 12, 31, 6, 29, 37),
#  datetime.datetime(2000, 12, 31, 6, 29, 37),
#  datetime.datetime(2000, 12, 31, 6, 30, 5),
#  datetime.datetime(2000, 12, 31, 6, 30, 5),
#  datetime.datetime(2000, 12, 31, 6, 30, 5),
#  datetime.datetime(2000, 12, 31, 6, 34, 53),
#  datetime.datetime(2000, 12, 31, 6, 34, 53),
#  datetime.datetime(2000, 12, 31, 6, 34, 53),
#  datetime.datetime(2000, 12, 31, 6, 34, 53),
#  datetime.datetime(2000, 12, 31, 6, 34, 53),
#  datetime.datetime(2000, 12, 31, 6, 35, 17),
#  datetime.datetime(2000, 12, 31, 6, 35, 40),
#  datetime.datetime(2000, 12, 31, 6, 35, 40),
#  datetime.datetime(2000, 12, 31, 6, 35, 40),
#  datetime.datetime(2000, 12, 31, 6, 35, 40),
#  datetime.datetime(2000, 12, 31, 6, 36, 8),
#  datetime.datetime(2000, 12, 31, 6, 36, 8),
#  datetime.datetime(2000, 12, 31, 6, 36, 8),
#  datetime.datetime(2000, 12, 31, 6, 36, 43),
#  datetime.datetime(2000, 12, 31, 6, 36, 43),
#  datetime.datetime(2000, 12, 31, 6, 36, 43),
#  datetime.datetime(2000, 12, 31, 6, 36, 43),
#  datetime.datetime(2000, 12, 31, 6, 37, 4),
#  datetime.datetime(2000, 12, 31, 6, 37, 4),
#  datetime.datetime(2000, 12, 31, 6, 37, 47),
#  datetime.datetime(2000, 12, 31, 6, 37, 47),
#  datetime.datetime(2000, 12, 31, 6, 38, 12),
#  datetime.datetime(2000, 12, 31, 6, 39, 19),
#  datetime.datetime(2000, 12, 31, 6, 39, 19),
#  datetime.datetime(2000, 12, 31, 6, 39, 19),
#  datetime.datetime(2000, 12, 31, 6, 40, 8),
#  datetime.datetime(2000, 12, 31, 6, 40, 8),
#  datetime.datetime(2000, 12, 31, 6, 40, 8),
#  datetime.datetime(2000, 12, 31, 6, 40, 8),
#  datetime.datetime(2000, 12, 31, 6, 40, 30),
#  datetime.datetime(2000, 12, 31, 6, 40, 52),
#  datetime.datetime(2000, 12, 31, 6, 40, 52),
#  datetime.datetime(2000, 12, 31, 6, 41, 33),
#  datetime.datetime(2000, 12, 31, 6, 41, 33),
#  datetime.datetime(2000, 12, 31, 6, 42, 42),
#  datetime.datetime(2000, 12, 31, 6, 42, 42),
#  datetime.datetime(2000, 12, 31, 6, 42, 42),
#  datetime.datetime(2000, 12, 31, 6, 42, 42),
#  datetime.datetime(2000, 12, 31, 6, 43, 57),
#  datetime.datetime(2000, 12, 31, 6, 43, 57),
#  datetime.datetime(2000, 12, 31, 6, 43, 57),
#  datetime.datetime(2000, 12, 31, 6, 44, 25),
#  datetime.datetime(2000, 12, 31, 6, 44, 25),
#  datetime.datetime(2000, 12, 31, 6, 44, 25),
#  datetime.datetime(2000, 12, 31, 6, 44, 25),
#  datetime.datetime(2000, 12, 31, 6, 48, 34),
#  datetime.datetime(2000, 12, 31, 6, 48, 34),
#  datetime.datetime(2000, 12, 31, 6, 48, 34),
#  datetime.datetime(2000, 12, 31, 6, 48, 34),
#  datetime.datetime(2000, 12, 31, 6, 48, 34),
#  datetime.datetime(2000, 12, 31, 6, 48, 54),
#  datetime.datetime(2000, 12, 31, 6, 48, 54),
#  datetime.datetime(2000, 12, 31, 6, 48, 54),
#  datetime.datetime(2000, 12, 31, 6, 50, 22),
#  datetime.datetime(2000, 12, 31, 6, 50, 22),
#  datetime.datetime(2000, 12, 31, 6, 50, 45),
#  datetime.datetime(2000, 12, 31, 6, 50, 45),
#  datetime.datetime(2000, 12, 31, 6, 51, 27),
#  datetime.datetime(2000, 12, 31, 6, 51, 53),
#  datetime.datetime(2000, 12, 31, 6, 51, 53),
#  datetime.datetime(2000, 12, 31, 6, 52, 28),
#  datetime.datetime(2000, 12, 31, 6, 52, 48),
#  datetime.datetime(2000, 12, 31, 6, 52, 48),
#  datetime.datetime(2000, 12, 31, 6, 52, 48),
#  datetime.datetime(2000, 12, 31, 6, 54, 5),
#  datetime.datetime(2000, 12, 31, 6, 54, 5),
#  datetime.datetime(2000, 12, 31, 6, 54, 5),
#  datetime.datetime(2000, 12, 31, 6, 54, 5),
#  datetime.datetime(2000, 12, 31, 6, 54, 5),
#  datetime.datetime(2000, 12, 31, 6, 54, 23),
#  datetime.datetime(2000, 12, 31, 6, 54, 47),
#  datetime.datetime(2000, 12, 31, 6, 54, 55),
#  datetime.datetime(2000, 12, 31, 6, 55, 8),
#  datetime.datetime(2000, 12, 31, 6, 55, 40),
#  datetime.datetime(2000, 12, 31, 6, 55, 40),
#  datetime.datetime(2000, 12, 31, 6, 56, 3),
#  datetime.datetime(2000, 12, 31, 6, 56, 3),
#  datetime.datetime(2000, 12, 31, 6, 56, 3),
#  datetime.datetime(2000, 12, 31, 6, 56, 3),
#  datetime.datetime(2000, 12, 31, 6, 56, 30),
#  datetime.datetime(2000, 12, 31, 6, 56, 30),
#  datetime.datetime(2000, 12, 31, 6, 57, 9),
#  datetime.datetime(2000, 12, 31, 6, 57, 9),
#  datetime.datetime(2000, 12, 31, 6, 57, 9),
#  datetime.datetime(2000, 12, 31, 6, 57, 9),
#  datetime.datetime(2000, 12, 31, 6, 57, 43),
#  datetime.datetime(2000, 12, 31, 6, 57, 43),
#  datetime.datetime(2000, 12, 31, 6, 58, 11),
#  datetime.datetime(2000, 12, 31, 6, 58, 11),
#  datetime.datetime(2000, 12, 31, 6, 58, 11),
#  datetime.datetime(2000, 12, 31, 6, 58, 11),
#  datetime.datetime(2000, 12, 31, 6, 58, 36),
#  datetime.datetime(2000, 12, 31, 6, 58, 36),
#  datetime.datetime(2000, 12, 31, 6, 58, 36),
#  datetime.datetime(2000, 12, 31, 6, 58, 36),
#  datetime.datetime(2000, 12, 31, 6, 58, 36),
#  datetime.datetime(2000, 12, 31, 6, 58, 51),
#  datetime.datetime(2000, 12, 31, 6, 59, 8),
#  datetime.datetime(2000, 12, 31, 6, 59, 8),
#  datetime.datetime(2000, 12, 31, 6, 59, 26),
#  datetime.datetime(2000, 12, 31, 6, 59, 59),
#  datetime.datetime(2000, 12, 31, 6, 59, 59),
#  datetime.datetime(2000, 12, 31, 6, 59, 59),
#  datetime.datetime(2000, 12, 31, 7, 0, 33),
#  datetime.datetime(2000, 12, 31, 7, 0, 33),
#  datetime.datetime(2000, 12, 31, 7, 1, 48),
#  datetime.datetime(2000, 12, 31, 7, 1, 48),
#  datetime.datetime(2000, 12, 31, 7, 1, 48),
#  datetime.datetime(2000, 12, 31, 7, 2, 42),
#  datetime.datetime(2000, 12, 31, 7, 2, 42),
#  datetime.datetime(2000, 12, 31, 7, 2, 42),
#  datetime.datetime(2000, 12, 31, 7, 2, 42),
#  datetime.datetime(2000, 12, 31, 7, 7, 6),
#  datetime.datetime(2000, 12, 31, 7, 7, 6),
#  datetime.datetime(2000, 12, 31, 7, 7, 30),
#  datetime.datetime(2000, 12, 31, 7, 7, 30),
#  datetime.datetime(2000, 12, 31, 7, 7, 59),
#  datetime.datetime(2000, 12, 31, 7, 7, 59),
#  datetime.datetime(2000, 12, 31, 7, 7, 59),
#  datetime.datetime(2000, 12, 31, 7, 8, 24),
#  datetime.datetime(2000, 12, 31, 7, 8, 24),
#  datetime.datetime(2000, 12, 31, 7, 8, 48),
#  datetime.datetime(2000, 12, 31, 7, 9, 15),
#  datetime.datetime(2000, 12, 31, 7, 9, 36),
#  datetime.datetime(2000, 12, 31, 7, 9, 36),
#  datetime.datetime(2000, 12, 31, 7, 9, 36),
#  datetime.datetime(2000, 12, 31, 7, 9, 45),
#  datetime.datetime(2000, 12, 31, 4, 14, 35),
#  datetime.datetime(2000, 12, 31, 4, 15, 22),
#  datetime.datetime(2000, 12, 31, 4, 15, 22),
#  datetime.datetime(2000, 12, 31, 4, 16, 59),
#  datetime.datetime(2000, 12, 31, 4, 16, 59),
#  datetime.datetime(2000, 12, 31, 4, 16, 59),
#  datetime.datetime(2000, 12, 31, 4, 19, 43),
#  datetime.datetime(2000, 12, 31, 4, 19, 43),
#  datetime.datetime(2000, 12, 31, 4, 19, 43),
#  datetime.datetime(2000, 12, 31, 4, 21, 59),
#  datetime.datetime(2000, 12, 31, 4, 21, 59),
#  datetime.datetime(2000, 12, 31, 4, 22, 47),
#  datetime.datetime(2000, 12, 31, 4, 22, 47),
#  datetime.datetime(2000, 12, 31, 4, 22, 47),
#  datetime.datetime(2000, 12, 31, 4, 22, 47),
#  datetime.datetime(2000, 12, 31, 4, 23, 32),
#  datetime.datetime(2000, 12, 31, 4, 23, 32),
#  datetime.datetime(2000, 12, 31, 4, 24, 30),
#  datetime.datetime(2000, 12, 31, 4, 24, 30),
#  datetime.datetime(2000, 12, 31, 4, 24, 30),
#  datetime.datetime(2000, 12, 31, 4, 24, 30),
#  datetime.datetime(2000, 12, 31, 4, 24, 30),
#  datetime.datetime(2000, 12, 31, 4, 25, 19),
#  datetime.datetime(2000, 12, 31, 4, 26, 11),
#  datetime.datetime(2000, 12, 31, 4, 26, 49),
#  datetime.datetime(2000, 12, 31, 4, 26, 49),
#  datetime.datetime(2000, 12, 31, 4, 27, 56),
#  datetime.datetime(2000, 12, 31, 4, 27, 56),
#  datetime.datetime(2000, 12, 31, 4, 29, 35),
#  datetime.datetime(2000, 12, 31, 4, 29, 35),
#  datetime.datetime(2000, 12, 31, 4, 30, 8),
#  datetime.datetime(2000, 12, 31, 4, 30, 34),
#  datetime.datetime(2000, 12, 31, 4, 33, 52),
#  datetime.datetime(2000, 12, 31, 4, 34, 33),
#  datetime.datetime(2000, 12, 31, 4, 36, 19),
#  datetime.datetime(2000, 12, 31, 4, 37, 24),
#  datetime.datetime(2000, 12, 31, 4, 37, 24),
#  datetime.datetime(2000, 12, 31, 4, 38, 31),
#  datetime.datetime(2000, 12, 31, 4, 38, 31),
#  datetime.datetime(2000, 12, 31, 4, 39, 30),
#  datetime.datetime(2000, 12, 31, 4, 39, 30),
#  datetime.datetime(2000, 12, 31, 4, 39, 30),
#  datetime.datetime(2000, 12, 31, 4, 39, 30),
#  datetime.datetime(2000, 12, 31, 4, 39, 30),
#  datetime.datetime(2000, 12, 31, 4, 41, 31),
#  datetime.datetime(2000, 12, 31, 4, 41, 31),
#  datetime.datetime(2000, 12, 31, 4, 42, 47),
#  datetime.datetime(2000, 12, 31, 4, 42, 47),
#  datetime.datetime(2000, 12, 31, 4, 42, 47),
#  datetime.datetime(2000, 12, 31, 4, 42, 47),
#  datetime.datetime(2000, 12, 31, 4, 42, 47),
#  datetime.datetime(2000, 12, 31, 4, 43, 33),
#  datetime.datetime(2000, 12, 31, 4, 43, 33),
#  datetime.datetime(2000, 12, 31, 4, 43, 33),
#  datetime.datetime(2000, 12, 31, 4, 45, 9),
#  datetime.datetime(2000, 12, 31, 4, 45, 9),
#  datetime.datetime(2000, 12, 31, 4, 45, 9),
#  datetime.datetime(2000, 12, 31, 4, 47, 16),
#  datetime.datetime(2000, 12, 31, 4, 47, 16),
#  datetime.datetime(2000, 12, 31, 4, 47, 16),
#  datetime.datetime(2000, 12, 31, 4, 47, 16),
#  datetime.datetime(2000, 12, 31, 4, 49, 55),
#  datetime.datetime(2000, 12, 31, 4, 49, 55),
#  datetime.datetime(2000, 12, 31, 4, 50, 30),
#  datetime.datetime(2000, 12, 31, 4, 50, 30),
#  datetime.datetime(2000, 12, 31, 4, 50, 56),
#  datetime.datetime(2000, 12, 31, 4, 51, 28),
#  datetime.datetime(2000, 12, 31, 4, 52, 51),
#  datetime.datetime(2000, 12, 31, 5, 0, 51),
#  datetime.datetime(2000, 12, 31, 5, 2, 28),
#  datetime.datetime(2000, 12, 31, 5, 3, 39),
#  datetime.datetime(2000, 12, 31, 3, 49, 41),
#  datetime.datetime(2000, 12, 31, 3, 50, 7),
#  datetime.datetime(2000, 12, 31, 3, 50, 32),
#  datetime.datetime(2000, 12, 31, 3, 50, 32),
#  datetime.datetime(2000, 12, 31, 3, 50, 59),
#  datetime.datetime(2000, 12, 31, 3, 52, 17),
#  datetime.datetime(2000, 12, 31, 3, 52, 17),
#  datetime.datetime(2000, 12, 31, 3, 52, 17),
#  datetime.datetime(2000, 12, 31, 3, 52, 17),
#  datetime.datetime(2000, 12, 31, 3, 52, 17),
#  datetime.datetime(2000, 12, 31, 3, 53, 6),
#  datetime.datetime(2000, 12, 31, 3, 53, 6),
#  datetime.datetime(2000, 12, 31, 3, 53, 6),
#  datetime.datetime(2000, 12, 31, 3, 53, 6),
#  datetime.datetime(2000, 12, 31, 3, 53, 6),
#  datetime.datetime(2000, 12, 31, 3, 53, 6),
#  datetime.datetime(2000, 12, 31, 3, 53, 30),
#  datetime.datetime(2000, 12, 31, 3, 53, 30),
#  datetime.datetime(2000, 12, 31, 3, 54, 2),
#  datetime.datetime(2000, 12, 31, 3, 54, 2),
#  datetime.datetime(2000, 12, 31, 3, 54, 2),
#  datetime.datetime(2000, 12, 31, 3, 54, 2),
#  datetime.datetime(2000, 12, 31, 3, 54, 2),
#  datetime.datetime(2000, 12, 31, 3, 54, 34),
#  datetime.datetime(2000, 12, 31, 3, 54, 34),
#  datetime.datetime(2000, 12, 31, 3, 54, 34),
#  datetime.datetime(2000, 12, 31, 3, 54, 34),
#  datetime.datetime(2000, 12, 31, 3, 54, 34),
#  datetime.datetime(2000, 12, 31, 3, 54, 34),
#  datetime.datetime(2000, 12, 31, 3, 54, 34),
#  datetime.datetime(2000, 12, 31, 3, 54, 58),
#  datetime.datetime(2000, 12, 31, 2, 13, 9),
#  datetime.datetime(2000, 12, 31, 2, 13, 52),
#  datetime.datetime(2000, 12, 31, 2, 14, 42),
#  datetime.datetime(2000, 12, 31, 2, 14, 42),
#  datetime.datetime(2000, 12, 31, 2, 16),
#  datetime.datetime(2000, 12, 31, 2, 16),
#  datetime.datetime(2000, 12, 31, 2, 18, 58),
#  datetime.datetime(2000, 12, 31, 2, 18, 58),
#  datetime.datetime(2000, 12, 31, 2, 18, 58),
#  datetime.datetime(2000, 12, 31, 2, 18, 58),
#  datetime.datetime(2000, 12, 31, 2, 18, 58),
#  datetime.datetime(2000, 12, 31, 2, 18, 58),
#  datetime.datetime(2000, 12, 31, 2, 19, 32),
#  datetime.datetime(2000, 12, 31, 2, 19, 32),
#  datetime.datetime(2000, 12, 31, 2, 19, 32),
#  datetime.datetime(2000, 12, 31, 2, 20, 4),
#  datetime.datetime(2000, 12, 31, 2, 20, 4),
#  datetime.datetime(2000, 12, 31, 2, 20, 4),
#  datetime.datetime(2000, 12, 31, 2, 20, 4),
#  datetime.datetime(2000, 12, 31, 2, 20, 46),
#  datetime.datetime(2000, 12, 31, 2, 20, 46),
#  datetime.datetime(2000, 12, 31, 2, 21, 33),
#  datetime.datetime(2000, 12, 31, 2, 21, 33),
#  datetime.datetime(2000, 12, 31, 2, 21, 33),
#  datetime.datetime(2000, 12, 31, 2, 21, 33),
#  datetime.datetime(2000, 12, 31, 2, 22, 27),
#  datetime.datetime(2000, 12, 31, 2, 22, 27),
#  datetime.datetime(2000, 12, 31, 2, 22, 27),
#  datetime.datetime(2000, 12, 31, 2, 22, 27),
#  datetime.datetime(2000, 12, 31, 2, 22, 27),
#  datetime.datetime(2000, 12, 31, 2, 23, 11),
#  datetime.datetime(2000, 12, 31, 2, 23, 11),
#  datetime.datetime(2000, 12, 31, 2, 24, 37),
#  datetime.datetime(2000, 12, 31, 2, 25, 24),
#  datetime.datetime(2000, 12, 31, 2, 25, 24),
#  datetime.datetime(2000, 12, 31, 2, 26, 11),
#  datetime.datetime(2000, 12, 31, 2, 26, 11),
#  datetime.datetime(2000, 12, 31, 2, 26, 11),
#  datetime.datetime(2000, 12, 31, 2, 26, 54),
#  datetime.datetime(2000, 12, 31, 2, 26, 54),
#  datetime.datetime(2000, 12, 31, 2, 26, 54),
#  datetime.datetime(2000, 12, 31, 2, 28, 22),
#  datetime.datetime(2000, 12, 31, 2, 28, 22),
#  datetime.datetime(2000, 12, 31, 2, 28, 22),
#  datetime.datetime(2000, 12, 31, 2, 30, 17),
#  datetime.datetime(2000, 12, 31, 2, 30, 17),
#  datetime.datetime(2000, 12, 31, 2, 30, 57),
#  datetime.datetime(2000, 12, 31, 2, 30, 57),
#  datetime.datetime(2000, 12, 31, 2, 30, 57),
#  datetime.datetime(2000, 12, 31, 2, 31, 40),
#  datetime.datetime(2000, 12, 31, 2, 31, 40),
#  datetime.datetime(2000, 12, 31, 2, 32, 37),
#  datetime.datetime(2000, 12, 31, 2, 32, 59),
#  datetime.datetime(2000, 12, 31, 2, 33, 33),
#  datetime.datetime(2000, 12, 31, 2, 33, 33),
#  datetime.datetime(2000, 12, 31, 2, 33, 33),
#  datetime.datetime(2000, 12, 31, 2, 34, 12),
#  datetime.datetime(2000, 12, 31, 2, 34, 12),
#  datetime.datetime(2000, 12, 31, 2, 34, 55),
#  datetime.datetime(2000, 12, 31, 2, 35, 20),
#  datetime.datetime(2000, 12, 31, 2, 35, 52),
#  datetime.datetime(2000, 12, 31, 2, 36, 24),
#  datetime.datetime(2000, 12, 31, 2, 36, 24),
#  datetime.datetime(2000, 12, 31, 2, 37, 7),
#  datetime.datetime(2000, 12, 31, 2, 37, 28),
#  datetime.datetime(2000, 12, 31, 2, 37, 28),
#  datetime.datetime(2000, 12, 31, 2, 38, 6),
#  datetime.datetime(2000, 12, 31, 2, 38, 6),
#  datetime.datetime(2000, 12, 31, 2, 39, 16),
#  datetime.datetime(2000, 12, 31, 2, 39, 51),
#  datetime.datetime(2000, 12, 31, 2, 39, 51),
#  datetime.datetime(2000, 12, 31, 2, 39, 51),
#  datetime.datetime(2000, 12, 31, 2, 39, 51),
#  datetime.datetime(2000, 12, 31, 2, 40, 35),
#  datetime.datetime(2000, 12, 31, 2, 40, 35),
#  datetime.datetime(2000, 12, 31, 2, 41, 23),
#  datetime.datetime(2000, 12, 31, 2, 41, 23),
#  datetime.datetime(2000, 12, 31, 2, 42, 30),
#  datetime.datetime(2000, 12, 31, 2, 42, 30),
#  datetime.datetime(2000, 12, 31, 2, 42, 57),
#  datetime.datetime(2000, 12, 31, 2, 43, 31),
#  datetime.datetime(2000, 12, 31, 2, 43, 31),
#  datetime.datetime(2000, 12, 31, 2, 43, 31),
#  datetime.datetime(2000, 12, 31, 2, 44, 9),
#  datetime.datetime(2000, 12, 31, 2, 44, 26),
#  datetime.datetime(2000, 12, 31, 2, 44, 47),
#  datetime.datetime(2000, 12, 31, 2, 45, 56),
#  datetime.datetime(2000, 12, 31, 2, 46, 40),
#  datetime.datetime(2000, 12, 31, 2, 46, 40),
#  datetime.datetime(2000, 12, 31, 2, 47, 32),
#  datetime.datetime(2000, 12, 31, 2, 47, 32),
#  datetime.datetime(2000, 12, 31, 2, 47, 32),
#  datetime.datetime(2000, 12, 31, 2, 48, 6),
#  datetime.datetime(2000, 12, 31, 2, 48, 6),
#  datetime.datetime(2000, 12, 31, 2, 49, 3),
#  datetime.datetime(2000, 12, 31, 2, 49, 3),
#  datetime.datetime(2000, 12, 31, 2, 49, 3),
#  datetime.datetime(2000, 12, 31, 2, 49, 3),
#  datetime.datetime(2000, 12, 31, 2, 49, 3),
#  datetime.datetime(2000, 12, 31, 2, 49, 26),
#  datetime.datetime(2000, 12, 31, 2, 49, 26),
#  datetime.datetime(2000, 12, 31, 2, 50, 31),
#  datetime.datetime(2000, 12, 31, 2, 50, 31),
#  datetime.datetime(2000, 12, 31, 2, 52, 1),
#  datetime.datetime(2000, 12, 31, 2, 52, 1),
#  datetime.datetime(2000, 12, 31, 2, 52, 30),
#  datetime.datetime(2000, 12, 31, 2, 52, 53),
#  datetime.datetime(2000, 12, 31, 2, 52, 53),
#  datetime.datetime(2000, 12, 31, 2, 54, 12),
#  datetime.datetime(2000, 12, 31, 2, 57, 9),
#  datetime.datetime(2000, 12, 31, 2, 58, 13),
#  datetime.datetime(2000, 12, 31, 2, 59, 31),
#  datetime.datetime(2000, 12, 31, 2, 59, 52),
#  datetime.datetime(2000, 12, 31, 3, 0, 14),
#  datetime.datetime(2000, 12, 31, 3, 0, 37),
#  datetime.datetime(2000, 12, 31, 3, 0, 59),
#  datetime.datetime(2000, 12, 31, 3, 1, 27),
#  datetime.datetime(2000, 12, 31, 3, 3, 22),
#  datetime.datetime(2000, 12, 31, 3, 3, 22),
#  datetime.datetime(2000, 12, 31, 3, 3, 22),
#  datetime.datetime(2000, 12, 31, 3, 4, 50),
#  datetime.datetime(2000, 12, 31, 3, 4, 50),
#  datetime.datetime(2000, 12, 31, 3, 6, 22),
#  datetime.datetime(2000, 12, 31, 3, 6, 22),
#  datetime.datetime(2000, 12, 31, 3, 6, 52),
#  datetime.datetime(2000, 12, 31, 3, 7, 36),
#  datetime.datetime(2000, 12, 31, 3, 7, 36),
#  datetime.datetime(2000, 12, 31, 3, 7, 36),
#  datetime.datetime(2000, 12, 31, 3, 7, 36),
#  datetime.datetime(2000, 12, 31, 3, 10, 3),
#  datetime.datetime(2000, 12, 31, 3, 10, 3),
#  datetime.datetime(2000, 12, 31, 3, 10, 31),
#  datetime.datetime(2000, 12, 31, 3, 19, 14),
#  datetime.datetime(2000, 12, 31, 3, 19, 14),
#  datetime.datetime(2000, 12, 31, 3, 31, 2),
#  datetime.datetime(2000, 12, 31, 3, 31, 2),
#  datetime.datetime(2000, 12, 31, 3, 31, 36),
#  datetime.datetime(2000, 12, 31, 3, 32, 6),
#  datetime.datetime(2000, 12, 31, 7, 19, 3),
#  datetime.datetime(2000, 12, 31, 1, 7, 39),
#  datetime.datetime(2000, 12, 31, 1, 7, 39),
#  datetime.datetime(2000, 12, 31, 1, 7, 59),
#  datetime.datetime(2000, 12, 31, 1, 8, 13),
#  datetime.datetime(2000, 12, 31, 1, 8, 28),
#  datetime.datetime(2000, 12, 31, 1, 8, 28),
#  datetime.datetime(2000, 12, 31, 1, 12, 33),
#  datetime.datetime(2000, 12, 31, 1, 12, 57),
#  datetime.datetime(2000, 12, 31, 1, 15, 3),
#  datetime.datetime(2000, 12, 31, 1, 15, 3),
#  datetime.datetime(2000, 12, 31, 1, 15, 14),
#  datetime.datetime(2000, 12, 31, 1, 15, 14),
#  datetime.datetime(2000, 12, 31, 1, 15, 33),
#  datetime.datetime(2000, 12, 31, 1, 15, 33),
#  datetime.datetime(2000, 12, 31, 1, 15, 33),
#  datetime.datetime(2000, 12, 31, 1, 16, 41),
#  datetime.datetime(2000, 12, 31, 1, 17, 9),
#  datetime.datetime(2000, 12, 31, 1, 17, 9),
#  datetime.datetime(2000, 12, 31, 1, 18, 9),
#  datetime.datetime(2000, 12, 31, 1, 19, 30),
#  datetime.datetime(2000, 12, 31, 1, 19, 30),
#  datetime.datetime(2000, 12, 31, 1, 19, 41),
#  datetime.datetime(2000, 12, 31, 1, 20, 13),
#  datetime.datetime(2000, 12, 31, 1, 21, 11),
#  datetime.datetime(2000, 12, 31, 1, 21, 26),
#  datetime.datetime(2000, 12, 31, 1, 21, 49),
#  datetime.datetime(2000, 12, 31, 1, 21, 58),
#  datetime.datetime(2000, 12, 31, 1, 22, 10),
#  datetime.datetime(2000, 12, 31, 1, 22, 26),
#  datetime.datetime(2000, 12, 31, 1, 22, 38),
#  datetime.datetime(2000, 12, 31, 1, 22, 58),
#  datetime.datetime(2000, 12, 31, 1, 23, 47),
#  datetime.datetime(2000, 12, 31, 1, 24, 43),
#  datetime.datetime(2000, 12, 31, 1, 24, 58),
#  datetime.datetime(2000, 12, 31, 1, 24, 58),
#  datetime.datetime(2000, 12, 31, 1, 24, 58),
#  datetime.datetime(2000, 12, 31, 1, 25, 8),
#  datetime.datetime(2000, 12, 31, 1, 25, 24),
#  datetime.datetime(2000, 12, 31, 1, 25, 24),
#  datetime.datetime(2000, 12, 31, 1, 25, 52),
#  datetime.datetime(2000, 12, 31, 1, 25, 52),
#  datetime.datetime(2000, 12, 31, 1, 25, 52),
#  datetime.datetime(2000, 12, 31, 1, 26, 8),
#  datetime.datetime(2000, 12, 31, 1, 26, 8),
#  datetime.datetime(2000, 12, 31, 1, 26, 24),
#  datetime.datetime(2000, 12, 31, 1, 26, 24),
#  datetime.datetime(2000, 12, 31, 1, 26, 24),
#  datetime.datetime(2000, 12, 31, 1, 26, 46),
#  datetime.datetime(2000, 12, 31, 1, 26, 46),
#  datetime.datetime(2000, 12, 31, 1, 27, 3),
#  datetime.datetime(2000, 12, 31, 1, 27, 21),
#  datetime.datetime(2000, 12, 31, 1, 27, 21),
#  datetime.datetime(2000, 12, 31, 1, 27, 21),
#  datetime.datetime(2000, 12, 31, 1, 27, 34),
#  datetime.datetime(2000, 12, 31, 1, 27, 46),
#  datetime.datetime(2000, 12, 31, 1, 27, 46),
#  datetime.datetime(2000, 12, 31, 1, 28, 1),
#  datetime.datetime(2000, 12, 31, 1, 28, 1),
#  datetime.datetime(2000, 12, 31, 1, 28, 13),
#  datetime.datetime(2000, 12, 31, 1, 28, 29),
#  datetime.datetime(2000, 12, 31, 1, 28, 29),
#  datetime.datetime(2000, 12, 31, 1, 28, 43),
#  datetime.datetime(2000, 12, 31, 1, 28, 43),
#  datetime.datetime(2000, 12, 31, 1, 29, 10),
#  datetime.datetime(2000, 12, 31, 1, 29, 10),
#  datetime.datetime(2000, 12, 31, 1, 29, 10),
#  datetime.datetime(2000, 12, 31, 1, 29, 25),
#  datetime.datetime(2000, 12, 31, 1, 29, 25),
#  datetime.datetime(2000, 12, 31, 1, 29, 25),
#  datetime.datetime(2000, 12, 31, 1, 29, 57),
#  datetime.datetime(2000, 12, 31, 1, 30, 7),
#  datetime.datetime(2000, 12, 31, 1, 30, 16),
#  datetime.datetime(2000, 12, 31, 1, 30, 33),
#  datetime.datetime(2000, 12, 31, 1, 30, 48),
#  datetime.datetime(2000, 12, 31, 1, 30, 48),
#  datetime.datetime(2000, 12, 31, 1, 30, 48),
#  datetime.datetime(2000, 12, 31, 1, 31, 1),
#  datetime.datetime(2000, 12, 31, 1, 31, 1),
#  datetime.datetime(2000, 12, 31, 1, 31, 1),
#  datetime.datetime(2000, 12, 31, 1, 31, 17),
#  datetime.datetime(2000, 12, 31, 1, 31, 31),
#  datetime.datetime(2000, 12, 31, 1, 31, 31),
#  datetime.datetime(2000, 12, 31, 1, 31, 42),
#  datetime.datetime(2000, 12, 31, 1, 31, 55),
#  datetime.datetime(2000, 12, 31, 1, 32, 8),
#  datetime.datetime(2000, 12, 31, 1, 32, 23),
#  datetime.datetime(2000, 12, 31, 1, 32, 48),
#  datetime.datetime(2000, 12, 31, 1, 33, 54),
#  datetime.datetime(2000, 12, 31, 1, 34, 8),
#  datetime.datetime(2000, 12, 31, 1, 34, 8),
#  datetime.datetime(2000, 12, 31, 1, 34, 23),
#  datetime.datetime(2000, 12, 31, 1, 34, 33),
#  datetime.datetime(2000, 12, 31, 1, 34, 55),
#  datetime.datetime(2000, 12, 31, 1, 34, 55),
#  datetime.datetime(2000, 12, 31, 1, 36, 4),
#  datetime.datetime(2000, 12, 31, 1, 36, 4),
#  datetime.datetime(2000, 12, 31, 1, 36, 4),
#  datetime.datetime(2000, 12, 31, 1, 36, 20),
#  datetime.datetime(2000, 12, 31, 1, 36, 39),
#  datetime.datetime(2000, 12, 31, 1, 36, 39),
#  datetime.datetime(2000, 12, 31, 1, 36, 59),
#  datetime.datetime(2000, 12, 31, 1, 37, 24),
#  datetime.datetime(2000, 12, 31, 1, 37, 45),
#  datetime.datetime(2000, 12, 31, 1, 37, 45),
#  datetime.datetime(2000, 12, 31, 1, 37, 58),
#  datetime.datetime(2000, 12, 31, 1, 37, 58),
#  datetime.datetime(2000, 12, 31, 0, 59, 35),
#  datetime.datetime(2000, 12, 31, 0, 59, 35),
#  datetime.datetime(2000, 12, 31, 0, 59, 35),
#  datetime.datetime(2000, 12, 31, 1, 0),
#  datetime.datetime(2000, 12, 31, 1, 0),
#  datetime.datetime(2000, 12, 31, 1, 2, 29),
#  datetime.datetime(2000, 12, 31, 1, 2, 29),
#  datetime.datetime(2000, 12, 31, 1, 2, 29),
#  datetime.datetime(2000, 12, 31, 1, 2, 29),
#  datetime.datetime(2000, 12, 31, 1, 3, 47),
#  datetime.datetime(2000, 12, 31, 1, 4, 35),
#  datetime.datetime(2000, 12, 31, 1, 5, 5),
#  datetime.datetime(2000, 12, 31, 1, 5, 5),
#  datetime.datetime(2000, 12, 31, 1, 5, 5),
#  datetime.datetime(2000, 12, 31, 1, 5, 49),
#  datetime.datetime(2000, 12, 31, 1, 6, 19),
#  datetime.datetime(2000, 12, 31, 1, 6, 19),
#  datetime.datetime(2000, 12, 31, 1, 6, 19),
#  datetime.datetime(2000, 12, 31, 1, 7, 1),
#  datetime.datetime(2000, 12, 31, 1, 8, 45),
#  datetime.datetime(2000, 12, 31, 1, 10, 33),
#  datetime.datetime(2000, 12, 31, 1, 10, 50),
#  datetime.datetime(2000, 12, 31, 1, 11, 10),
#  datetime.datetime(2000, 12, 31, 1, 17, 8),
#  datetime.datetime(2000, 12, 31, 1, 17, 36),
#  datetime.datetime(2000, 12, 31, 1, 19, 1),
#  datetime.datetime(2000, 12, 31, 1, 19, 1),
#  datetime.datetime(2000, 12, 31, 1, 19, 21),
#  datetime.datetime(2000, 12, 31, 1, 19, 59),
#  datetime.datetime(2000, 12, 31, 1, 20, 30),
#  datetime.datetime(2000, 12, 31, 1, 20, 30),
#  datetime.datetime(2000, 12, 31, 1, 20, 30),
#  datetime.datetime(2000, 12, 31, 1, 21, 22),
#  datetime.datetime(2000, 12, 31, 1, 21, 22),
#  datetime.datetime(2000, 12, 31, 1, 21, 22),
#  datetime.datetime(2000, 12, 31, 1, 21, 48),
#  datetime.datetime(2000, 12, 31, 1, 22, 15),
#  datetime.datetime(2000, 12, 31, 1, 22, 15),
#  datetime.datetime(2000, 12, 31, 1, 22, 15),
#  datetime.datetime(2000, 12, 31, 1, 22, 39),
#  datetime.datetime(2000, 12, 31, 1, 22, 59),
#  datetime.datetime(2000, 12, 31, 1, 23, 20),
#  datetime.datetime(2000, 12, 31, 1, 23, 20),
#  datetime.datetime(2000, 12, 31, 1, 23, 44),
#  datetime.datetime(2000, 12, 31, 1, 23, 44),
#  datetime.datetime(2000, 12, 31, 1, 24, 13),
#  datetime.datetime(2000, 12, 31, 1, 24, 13),
#  datetime.datetime(2000, 12, 31, 1, 25),
#  datetime.datetime(2000, 12, 31, 1, 25),
#  datetime.datetime(2000, 12, 31, 1, 25),
#  datetime.datetime(2000, 12, 31, 1, 25, 22),
#  datetime.datetime(2000, 12, 31, 1, 25, 22),
#  datetime.datetime(2000, 12, 31, 1, 25, 22),
#  datetime.datetime(2000, 12, 31, 1, 25, 52),
#  datetime.datetime(2000, 12, 31, 1, 25, 52),
#  datetime.datetime(2000, 12, 31, 1, 25, 52),
#  datetime.datetime(2000, 12, 31, 1, 26, 37),
#  datetime.datetime(2000, 12, 31, 1, 26, 37),
#  datetime.datetime(2000, 12, 31, 1, 27, 6),
#  datetime.datetime(2000, 12, 31, 1, 27, 48),
#  datetime.datetime(2000, 12, 31, 1, 28, 23),
#  datetime.datetime(2000, 12, 31, 1, 28, 23),
#  datetime.datetime(2000, 12, 31, 1, 28, 48),
#  datetime.datetime(2000, 12, 31, 1, 29, 7),
#  datetime.datetime(2000, 12, 31, 1, 29, 25),
#  datetime.datetime(2000, 12, 31, 1, 29, 25),
#  datetime.datetime(2000, 12, 31, 1, 29, 46),
#  datetime.datetime(2000, 12, 31, 1, 30, 12),
#  datetime.datetime(2000, 12, 31, 1, 30, 12),
#  datetime.datetime(2000, 12, 31, 1, 30, 12),
#  datetime.datetime(2000, 12, 31, 1, 30, 31),
#  datetime.datetime(2000, 12, 31, 1, 30, 54),
#  datetime.datetime(2000, 12, 31, 1, 31, 27),
#  datetime.datetime(2000, 12, 31, 1, 31, 27),
#  datetime.datetime(2000, 12, 31, 1, 31, 27),
#  datetime.datetime(2000, 12, 31, 1, 31, 59),
#  datetime.datetime(2000, 12, 31, 1, 31, 59),
#  datetime.datetime(2000, 12, 31, 1, 31, 59),
#  datetime.datetime(2000, 12, 31, 1, 32, 29),
#  datetime.datetime(2000, 12, 31, 1, 32, 29),
#  datetime.datetime(2000, 12, 31, 1, 32, 58),
#  datetime.datetime(2000, 12, 31, 1, 33, 21),
#  datetime.datetime(2000, 12, 31, 1, 33, 22),
#  datetime.datetime(2000, 12, 31, 1, 33, 45),
#  datetime.datetime(2000, 12, 31, 1, 34, 3),
#  datetime.datetime(2000, 12, 31, 1, 34, 34),
#  datetime.datetime(2000, 12, 31, 1, 34, 34),
#  datetime.datetime(2000, 12, 31, 1, 35),
#  datetime.datetime(2000, 12, 31, 1, 35),
#  datetime.datetime(2000, 12, 31, 1, 35),
#  datetime.datetime(2000, 12, 31, 1, 35),
#  datetime.datetime(2000, 12, 31, 1, 35, 46),
#  datetime.datetime(2000, 12, 31, 1, 36, 12),
#  datetime.datetime(2000, 12, 31, 1, 38, 18),
#  datetime.datetime(2000, 12, 31, 1, 38, 18),
#  datetime.datetime(2000, 12, 31, 1, 38, 59),
#  datetime.datetime(2000, 12, 31, 1, 38, 59),
#  datetime.datetime(2000, 12, 31, 1, 39, 26),
#  datetime.datetime(2000, 12, 31, 1, 40, 5),
#  datetime.datetime(2000, 12, 31, 1, 40, 5),
#  datetime.datetime(2000, 12, 31, 1, 40, 5),
#  datetime.datetime(2000, 12, 31, 1, 40, 33),
#  datetime.datetime(2000, 12, 31, 1, 41, 6),
#  datetime.datetime(2000, 12, 31, 1, 41, 6),
#  datetime.datetime(2000, 12, 31, 1, 41, 6),
#  datetime.datetime(2000, 12, 31, 1, 41, 6),
#  datetime.datetime(2000, 12, 31, 1, 41, 6),
#  datetime.datetime(2000, 12, 31, 1, 41, 36),
#  datetime.datetime(2000, 12, 31, 1, 41, 36),
#  datetime.datetime(2000, 12, 31, 1, 41, 53),
#  datetime.datetime(2000, 12, 31, 1, 42, 31),
#  datetime.datetime(2000, 12, 31, 1, 42, 48),
#  datetime.datetime(2000, 12, 31, 1, 43, 23),
#  datetime.datetime(2000, 12, 31, 1, 43, 23),
#  datetime.datetime(2000, 12, 31, 1, 43, 23),
#  datetime.datetime(2000, 12, 31, 1, 43, 48),
#  datetime.datetime(2000, 12, 31, 1, 43, 49),
#  datetime.datetime(2000, 12, 31, 1, 44, 11),
#  datetime.datetime(2000, 12, 31, 1, 44, 11),
#  datetime.datetime(2000, 12, 31, 1, 44, 47),
#  datetime.datetime(2000, 12, 31, 1, 45, 5),
#  datetime.datetime(2000, 12, 31, 1, 45, 25),
#  datetime.datetime(2000, 12, 31, 1, 45, 43),
#  datetime.datetime(2000, 12, 31, 1, 46, 6),
#  datetime.datetime(2000, 12, 31, 1, 46, 6),
#  datetime.datetime(2000, 12, 31, 1, 46, 28),
#  datetime.datetime(2000, 12, 31, 1, 46, 28),
#  datetime.datetime(2000, 12, 31, 1, 46, 55),
#  datetime.datetime(2000, 12, 31, 1, 46, 55),
#  datetime.datetime(2000, 12, 31, 1, 47, 19),
#  datetime.datetime(2000, 12, 31, 1, 47, 19),
#  datetime.datetime(2000, 12, 31, 1, 47, 43),
#  datetime.datetime(2000, 12, 31, 1, 47, 43),
#  datetime.datetime(2000, 12, 31, 1, 48, 20),
#  datetime.datetime(2000, 12, 31, 1, 48, 20),
#  datetime.datetime(2000, 12, 31, 1, 48, 20),
#  datetime.datetime(2000, 12, 31, 1, 48, 20),
#  datetime.datetime(2000, 12, 31, 1, 48, 37),
#  datetime.datetime(2000, 12, 31, 1, 48, 56),
#  datetime.datetime(2000, 12, 31, 1, 49, 39),
#  datetime.datetime(2000, 12, 31, 1, 50, 25),
#  datetime.datetime(2000, 12, 31, 1, 50, 42),
#  datetime.datetime(2000, 12, 31, 1, 51, 2),
#  datetime.datetime(2000, 12, 31, 1, 51, 21),
#  datetime.datetime(2000, 12, 31, 1, 51, 43),
#  datetime.datetime(2000, 12, 31, 1, 51, 43),
#  datetime.datetime(2000, 12, 31, 1, 52, 9),
#  datetime.datetime(2000, 12, 31, 1, 52, 31),
#  datetime.datetime(2000, 12, 31, 1, 52, 31),
#  datetime.datetime(2000, 12, 31, 1, 52, 54),
#  datetime.datetime(2000, 12, 31, 1, 53, 45),
#  datetime.datetime(2000, 12, 31, 1, 53, 45),
#  datetime.datetime(2000, 12, 31, 1, 53, 45),
#  datetime.datetime(2000, 12, 31, 1, 54, 6),
#  datetime.datetime(2000, 12, 31, 1, 54, 6),
#  datetime.datetime(2000, 12, 31, 1, 54, 29),
#  datetime.datetime(2000, 12, 31, 1, 54, 29),
#  datetime.datetime(2000, 12, 31, 1, 54, 29),
#  datetime.datetime(2000, 12, 31, 1, 54, 56),
#  datetime.datetime(2000, 12, 31, 1, 54, 56),
#  datetime.datetime(2000, 12, 31, 1, 56, 3),
#  datetime.datetime(2000, 12, 31, 1, 56, 3),
#  datetime.datetime(2000, 12, 31, 1, 56, 47),
#  datetime.datetime(2000, 12, 31, 1, 57, 22),
#  datetime.datetime(2000, 12, 31, 1, 57, 28),
#  datetime.datetime(2000, 12, 31, 1, 57, 51),
#  datetime.datetime(2000, 12, 31, 1, 57, 51),
#  datetime.datetime(2000, 12, 31, 1, 58, 32),
#  datetime.datetime(2000, 12, 31, 1, 58, 54),
#  datetime.datetime(2000, 12, 31, 1, 59, 21),
#  datetime.datetime(2000, 12, 31, 1, 59, 53),
#  datetime.datetime(2000, 12, 31, 2, 0, 53),
#  datetime.datetime(2000, 12, 31, 2, 0, 53),
#  datetime.datetime(2000, 12, 31, 2, 1, 14),
#  datetime.datetime(2000, 12, 31, 2, 1, 14),
#  datetime.datetime(2000, 12, 31, 2, 1, 58),
#  datetime.datetime(2000, 12, 31, 2, 1, 58),
#  datetime.datetime(2000, 12, 31, 2, 2, 33),
#  datetime.datetime(2000, 12, 31, 2, 2, 33),
#  datetime.datetime(2000, 12, 31, 2, 2, 54),
#  datetime.datetime(2000, 12, 31, 2, 2, 54),
#  datetime.datetime(2000, 12, 31, 2, 3, 32),
#  datetime.datetime(2000, 12, 31, 2, 3, 32),
#  datetime.datetime(2000, 12, 31, 2, 3, 32),
#  datetime.datetime(2000, 12, 31, 2, 4, 48),
#  datetime.datetime(2000, 12, 31, 2, 4, 48),
#  datetime.datetime(2000, 12, 31, 2, 5, 7),
#  datetime.datetime(2000, 12, 31, 2, 5, 7),
#  datetime.datetime(2000, 12, 31, 2, 6, 4),
#  datetime.datetime(2000, 12, 31, 2, 6, 4),
#  datetime.datetime(2000, 12, 31, 2, 6, 48),
#  datetime.datetime(2000, 12, 31, 2, 6, 48),
#  datetime.datetime(2000, 12, 31, 2, 7, 8),
#  datetime.datetime(2000, 12, 31, 2, 7, 31),
#  datetime.datetime(2000, 12, 31, 2, 7, 31),
#  datetime.datetime(2000, 12, 31, 2, 8, 45),
#  datetime.datetime(2000, 12, 31, 2, 9, 6),
#  datetime.datetime(2000, 12, 31, 2, 9, 35),
#  datetime.datetime(2000, 12, 31, 2, 10, 1),
#  datetime.datetime(2000, 12, 31, 2, 10, 1),
#  datetime.datetime(2000, 12, 31, 2, 10, 1),
#  ...]

# %%
data["Time"] = a
data
# Out:
#          UserId  ItemId  Rating                Time
# 31            1    3186       4 2000-12-31 22:00:19
# 22            1    1270       5 2000-12-31 22:00:55
# 27            1    1721       4 2000-12-31 22:00:55
# 37            1    1022       5 2000-12-31 22:00:55
# 24            1    2340       3 2000-12-31 22:01:43
# ...         ...     ...     ...                 ...
# 1000019    6040    2917       4 2001-08-10 14:40:29
# 999988     6040    1921       4 2001-08-10 14:41:04
# 1000172    6040    1784       3 2001-08-10 14:41:04
# 1000167    6040     161       3 2001-08-10 14:41:26
# 1000042    6040    1221       4 2001-08-20 13:44:15
#
# [1000209 rows x 4 columns]

# %% [markdown]
# # Session Length
# 세션이 몇개의 클릭 데이터를 갖는지 보기

# %% [markdown]
# ###### SessionId를 공유하는 데이터 row의 개수

# %%
session_length = data.groupby('UserId').size()
session_length
# Out:
# UserId
# 1        53
# 2       129
# 3        51
# 4        21
# 5       198
#        ...
# 6036    888
# 6037    202
# 6038     20
# 6039    123
# 6040    341
# Length: 6040, dtype: int64

# %%
session_length.median(), session_length.mean()
# Out:
# (96.0, 165.5975165562914)

# %%
session_length.min(), session_length.max()
# Out:
# (20, 2314)

# %%
session_length.quantile(0.999)
# Out:
# 1343.181000000005

# %% [markdown]
# * 분위수(quantile)
# 99.9%의 세션길이가 1343 이하

# %% [markdown]
# ###### 2314인 애는 뭐야?

# %%
long_session = session_length[session_length==2314].index[0]
data[data['UserId']==long_session]
# Out:
#         UserId  ItemId  Rating                Time
# 696969    4169    1268       5 2000-08-03 20:09:52
# 697168    4169    2617       4 2000-08-03 20:09:52
# 697185    4169    2628       4 2000-08-03 20:09:52
# 697219    4169    2653       4 2000-08-03 20:09:52
# 697275    4169     423       3 2000-08-03 20:09:52
# ...        ...     ...     ...                 ...
# 697882    4169    3754       2 2002-06-15 20:52:27
# 695702    4169    1413       3 2002-06-15 21:03:51
# 697358    4169     494       4 2002-06-15 21:16:00
# 695945    4169    1804       2 2002-06-15 21:16:23
# 696446    4169    1548       3 2002-06-15 21:25:37
#
# [2314 rows x 4 columns]

# %% [markdown]
# * 매우 짧은 간격으로 한놈이 지속적으로 클릭을 1시간 30분 가량 지속

# %% [markdown]
# ###### 세션길이 기준 하위 99.9%까지의 분포 누적합

# %%
length_count = session_length.groupby(session_length).size()
length_percent_cumsum = length_count.cumsum() / length_count.sum()
length_percent_cumsum_999 = length_percent_cumsum[length_percent_cumsum < 0.999]

length_percent_cumsum_999
# Out:
# 20      0.014238
# 21      0.029305
# 22      0.042053
# 23      0.055464
# 24      0.068874
#           ...
# 1271    0.998179
# 1277    0.998344
# 1286    0.998510
# 1302    0.998675
# 1323    0.998841
# Length: 736, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))
plt.bar(x=length_percent_cumsum_999.index,
        height=length_percent_cumsum_999, color='red')
plt.xticks(length_percent_cumsum_999.index)
plt.yticks(np.arange(0, 1.01, 0.05))
plt.title('Cumsum Percentage Until 0.999', size=20)
plt.show()

# %%
data['Time'] = pd.to_datetime(data['Time'], unit='s')

# %%
data
# Out:
#          UserId  ItemId  Rating                Time
# 31            1    3186       4 2000-12-31 22:00:19
# 22            1    1270       5 2000-12-31 22:00:55
# 27            1    1721       4 2000-12-31 22:00:55
# 37            1    1022       5 2000-12-31 22:00:55
# 24            1    2340       3 2000-12-31 22:01:43
# ...         ...     ...     ...                 ...
# 1000019    6040    2917       4 2001-08-10 14:40:29
# 999988     6040    1921       4 2001-08-10 14:41:04
# 1000172    6040    1784       3 2001-08-10 14:41:04
# 1000167    6040     161       3 2001-08-10 14:41:26
# 1000042    6040    1221       4 2001-08-20 13:44:15
#
# [1000209 rows x 4 columns]

# %% [markdown]
# # Session Time

# %%
oldest, latest = data['Time'].min(), data['Time'].max()
print(oldest)
print(latest)
# Out:
# 2000-04-25 23:05:32
# 2003-02-28 17:49:50

# %% [markdown]
# 2000년 4월 25일 ~ 2003년 2월 28일 데이터

# %% [markdown]
# # Data Cleansing

# %%
# short_session을 제거한 다음 unpopular item을 제거하면 다시 길이가 1인 session이 생길 수 있습니다.
# 이를 위해 반복문을 통해 지속적으로 제거 합니다.
def cleanse_recursive(data: pd.DataFrame, shortest, least_click) -> pd.DataFrame:
    while True:
        before_len = len(data)
        data = cleanse_short_session(data, shortest)
        data = cleanse_unpopular_item(data, least_click)
        after_len = len(data)
        if before_len == after_len:
            break
    return data


def cleanse_short_session(data: pd.DataFrame, shortest):
    session_len = data.groupby('UserId').size()
    session_use = session_len[session_len >= shortest].index
    data = data[data['UserId'].isin(session_use)]
    return data


def cleanse_unpopular_item(data: pd.DataFrame, least_click):
    item_popular = data.groupby('ItemId').size()
    item_use = item_popular[item_popular >= least_click].index
    data = data[data['ItemId'].isin(item_use)]
    return data

# %% [markdown]
# ##### 세션길이2, 클릭횟수 5이하의 데이터 제거

# %%
data = cleanse_recursive(data, shortest=2, least_click=5)
data
# Out:
#          UserId  ItemId  Rating                Time
# 31            1    3186       4 2000-12-31 22:00:19
# 22            1    1270       5 2000-12-31 22:00:55
# 27            1    1721       4 2000-12-31 22:00:55
# 37            1    1022       5 2000-12-31 22:00:55
# 24            1    2340       3 2000-12-31 22:01:43
# ...         ...     ...     ...                 ...
# 1000019    6040    2917       4 2001-08-10 14:40:29
# 999988     6040    1921       4 2001-08-10 14:41:04
# 1000172    6040    1784       3 2001-08-10 14:41:04
# 1000167    6040     161       3 2001-08-10 14:41:26
# 1000042    6040    1221       4 2001-08-20 13:44:15
#
# [999611 rows x 4 columns]

# %% [markdown]
# # Train/ Valid/ Test split

# %% [markdown]
# ##### 이번 자료에서는 가장 마지막 1일 기간 동안을 Test로, 2일전부터 1일전 까지를 valid set으로 나누겠습니다.

# %%
def split_by_date(data: pd.DataFrame, n_days: int):
    final_time = data['Time'].max()
    session_last_time = data.groupby('UserId')['Time'].max()
    session_in_train = session_last_time[session_last_time < final_time - dt.timedelta(n_days)].index
    session_in_test = session_last_time[session_last_time >= final_time - dt.timedelta(n_days)].index
    
    before_date = data[data['UserId'].isin(session_in_train)]
    after_date = data[data['UserId'].isin(session_in_test)]
    after_date = after_date[after_date['ItemId'].isin(before_date['ItemId'])]
    return before_date, after_date

# %%
tr, test = split_by_date(data, n_days=180) # 3년치 중 대략 3개월 치 test
tr, val = split_by_date(tr, n_days=180) #3년치 중 대략 3개월 치 val 나머지 train

# %%
# data에 대한 정보를 살펴봅니다.
def stats_info(data: pd.DataFrame, status: str):
    print(f'* {status} Set Stats Info\n'
          f'\t Events: {len(data)}\n'
          f'\t Sessions: {data["UserId"].nunique()}\n'
          f'\t Items: {data["ItemId"].nunique()}\n'
          f'\t First Time : {data["Time"].min()}\n'
          f'\t Last Time : {data["Time"].max()}\n')

# %%
stats_info(tr, 'train')
stats_info(val, 'valid')
stats_info(test, 'test')
# Out:
# * train Set Stats Info
# 	 Events: 919209
# 	 Sessions: 5858
# 	 Items: 3416
# 	 First Time : 2000-04-25 23:05:32
# 	 Last Time : 2002-12-30 02:26:14
#
# * valid Set Stats Info
# 	 Events: 29477
# 	 Sessions: 79
# 	 Items: 2960
# 	 First Time : 2000-05-05 17:20:21
# 	 Last Time : 2003-01-29 03:00:40
#
# * test Set Stats Info
# 	 Events: 50925
# 	 Sessions: 103
# 	 Items: 3172
# 	 First Time : 2000-05-01 11:15:13
# 	 Last Time : 2003-02-28 17:49:50

# %%
# train set에 없는 아이템이 val, test기간에 생길 수 있으므로 train data를 기준으로 인덱싱합니다.
id2idx = {item_id : index for index, item_id in enumerate(tr['ItemId'].unique())}

def indexing(df, id2idx):
    df['item_idx'] = df['ItemId'].map(lambda x: id2idx.get(x, -1))  # id2idx에 없는 아이템은 모르는 값(-1) 처리 해줍니다.
    return df

tr = indexing(tr, id2idx)
val = indexing(val, id2idx)
test = indexing(test, id2idx)

# %%
save_path = data_path / 'processed'
save_path.mkdir(parents=True, exist_ok=True)

tr.to_pickle(save_path / 'train.pkl')
val.to_pickle(save_path / 'valid.pkl')
test.to_pickle(save_path / 'test.pkl')

# %% [markdown]
# # SessionDataset

# %%
class SessionDataset:
    """Credit to yhs-968/pyGRU4REC."""

    def __init__(self, data):
        self.df = data
        self.click_offsets = self.get_click_offsets()
        self.session_idx = np.arange(self.df['UserId'].nunique())  # indexing to UserId

    def get_click_offsets(self):
        """
        Return the indexes of the first click of each session IDs,
        """
        offsets = np.zeros(self.df['UserId'].nunique() + 1, dtype=np.int32)
        offsets[1:] = self.df.groupby('UserId').size().cumsum()
        return offsets

# %%
tr_dataset = SessionDataset(tr)
tr_dataset.df.head(10)
# Out:
#     UserId  ItemId  Rating                Time  item_idx
# 31       1    3186       4 2000-12-31 22:00:19         0
# 22       1    1270       5 2000-12-31 22:00:55         1
# 27       1    1721       4 2000-12-31 22:00:55         2
# 37       1    1022       5 2000-12-31 22:00:55         3
# 24       1    2340       3 2000-12-31 22:01:43         4
# 36       1    1836       5 2000-12-31 22:02:52         5
# 3        1    3408       4 2000-12-31 22:04:35         6
# 7        1    2804       5 2000-12-31 22:11:59         7
# 47       1    1207       4 2000-12-31 22:11:59         8
# 0        1    1193       5 2000-12-31 22:12:40         9

# %%
tr_dataset.click_offsets
# Out:
# array([     0,     53,    182, ..., 918745, 918868, 919209], dtype=int32)

# %%
tr_dataset.session_idx
# Out:
# array([   0,    1,    2, ..., 5855, 5856, 5857])

# %% [markdown]
# # SessionDataLoader

# %%
class SessionDataLoader:
    """Credit to yhs-968/pyGRU4REC."""

    def __init__(self, dataset: SessionDataset, batch_size=128):
        self.dataset = dataset
        self.batch_size = batch_size

    def __iter__(self):
        """ Returns the iterator for producing session-parallel training mini-batches.
        Yields:
            input (B,):  Item indices that will be encoded as one-hot vectors later.
            target (B,): a Variable that stores the target item indices
            masks: Numpy array indicating the positions of the sessions to be terminated
        """

        start, end, mask, last_session, finished = self.initialize()  # initialize 메소드에서 확인해주세요.
        """
        start : Index Where Session Start
        end : Index Where Session End
        mask : indicator for the sessions to be terminated
        """

        while not finished:
            min_len = (end - start).min() - 1  # Shortest Length Among Sessions
            for i in range(min_len):
                # Build inputs & targets
                inp = self.dataset.df['item_idx'].values[start + i]
                target = self.dataset.df['item_idx'].values[start + i + 1]
                yield inp, target, mask

            start, end, mask, last_session, finished = self.update_status(start, end, min_len, last_session, finished)

    def initialize(self):
        first_iters = np.arange(self.batch_size)    # 첫 배치에 사용할 세션 Index를 가져옵니다.
        last_session = self.batch_size - 1    # 마지막으로 다루고 있는 세션 Index를 저장해둡니다.
        start = self.dataset.click_offsets[self.dataset.session_idx[first_iters]]       # data 상에서 session이 시작된 위치를 가져옵니다.
        end = self.dataset.click_offsets[self.dataset.session_idx[first_iters] + 1]  # session이 끝난 위치 바로 다음 위치를 가져옵니다.
        mask = np.array([])   # session의 모든 아이템을 다 돌은 경우 mask에 추가해줄 것입니다.
        finished = False         # data를 전부 돌았는지 기록하기 위한 변수입니다.
        return start, end, mask, last_session, finished

    def update_status(self, start: np.ndarray, end: np.ndarray, min_len: int, last_session: int, finished: bool):  
        # 다음 배치 데이터를 생성하기 위해 상태를 update합니다.
        
        start += min_len   # __iter__에서 min_len 만큼 for문을 돌았으므로 start를 min_len 만큼 더해줍니다.
        mask = np.arange(self.batch_size)[(end - start) == 1]  
        # end는 다음 세션이 시작되는 위치인데 start와 한 칸 차이난다는 것은 session이 끝났다는 뜻입니다. mask에 기록해줍니다.

        for i, idx in enumerate(mask, start=1):  # mask에 추가된 세션 개수만큼 새로운 세션을 돌것입니다.
            new_session = last_session + i  
            if new_session > self.dataset.session_idx[-1]:  # 만약 새로운 세션이 마지막 세션 index보다 크다면 모든 학습데이터를 돈 것입니다.
                finished = True
                break
            # update the next starting/ending point
            start[idx] = self.dataset.click_offsets[self.dataset.session_idx[new_session]]     # 종료된 세션 대신 새로운 세션의 시작점을 기록합니다.
            end[idx] = self.dataset.click_offsets[self.dataset.session_idx[new_session] + 1]

        last_session += len(mask)  # 마지막 세션의 위치를 기록해둡니다.
        return start, end, mask, last_session, finished

# %%
tr_data_loader = SessionDataLoader(tr_dataset, batch_size=4)
tr_dataset.df.head(15)
# Out:
#     UserId  ItemId  Rating                Time  item_idx
# 31       1    3186       4 2000-12-31 22:00:19         0
# 22       1    1270       5 2000-12-31 22:00:55         1
# 27       1    1721       4 2000-12-31 22:00:55         2
# 37       1    1022       5 2000-12-31 22:00:55         3
# 24       1    2340       3 2000-12-31 22:01:43         4
# 36       1    1836       5 2000-12-31 22:02:52         5
# 3        1    3408       4 2000-12-31 22:04:35         6
# 7        1    2804       5 2000-12-31 22:11:59         7
# 47       1    1207       4 2000-12-31 22:11:59         8
# 0        1    1193       5 2000-12-31 22:12:40         9
# 21       1     720       3 2000-12-31 22:12:40        10
# 44       1     260       4 2000-12-31 22:12:40        11
# 9        1     919       4 2000-12-31 22:22:48        12
# 51       1     608       4 2000-12-31 22:23:18        13
# 43       1    2692       4 2000-12-31 22:26:10        14

# %%
iter_ex = iter(tr_data_loader)

# %%
inputs, labels, mask =  next(iter_ex)
print(f'Model Input Item Idx are : {inputs}')
print(f'Label Item Idx are : {"":5} {labels}')
print(f'Previous Masked Input Idx are {mask}')
# Out:
# Model Input Item Idx are : [ 0 53 65 54]
# Label Item Idx are :       [ 1 54 62 24]
# Previous Masked Input Idx are []

# %% [markdown]
# #  Modeling
# Evaluation Metric

# %%
def mrr_k(pred, truth: int, k: int):
    indexing = np.where(pred[:k] == truth)[0]
    if len(indexing) > 0:
        return 1 / (indexing[0] + 1)
    else:
        return 0


def recall_k(pred, truth: int, k: int) -> int:
    answer = truth in pred[:k]
    return int(answer)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout, GRU
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tqdm import tqdm

# %%
def create_model(args):
    inputs = Input(batch_shape=(args.batch_size, 1, args.num_items))
    gru, _ = GRU(args.hsz, stateful=True, return_state=True, name='GRU')(inputs)
    dropout = Dropout(args.drop_rate)(gru)
    predictions = Dense(args.num_items, activation='softmax')(dropout)
    model = Model(inputs=inputs, outputs=[predictions])
    model.compile(loss=categorical_crossentropy, optimizer=Adam(args.lr), metrics=['accuracy'])
    model.summary()
    return model

# %%
class Args:
    def __init__(self, tr, val, test, batch_size, hsz, drop_rate, lr, epochs, k):
        self.tr = tr
        self.val = val
        self.test = test
        self.num_items = tr['ItemId'].nunique()
        self.num_sessions = tr['UserId'].nunique()
        self.batch_size = batch_size
        self.hsz = hsz
        self.drop_rate = drop_rate
        self.lr = lr
        self.epochs = epochs
        self.k = k

args = Args(tr, val, test, batch_size=128, hsz=50, drop_rate=0.1, lr=0.001, epochs=3, k=20)

# %%
model = create_model(args)
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(128, 1, 3416)]          0
# _________________________________________________________________
# GRU (GRU)                    [(128, 50), (128, 50)]    520200
# _________________________________________________________________
# dropout_1 (Dropout)          (128, 50)                 0
# _________________________________________________________________
# dense_1 (Dense)              (128, 3416)               174216
# =================================================================
# Total params: 694,416
# Trainable params: 694,416
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train 셋으로 학습하면서 valid 셋으로 검증합니다.
def train_model(model, args):
    train_dataset = SessionDataset(args.tr)
    train_loader = SessionDataLoader(train_dataset, batch_size=args.batch_size)

    for epoch in range(1, args.epochs + 1):
        total_step = len(args.tr) - args.tr['UserId'].nunique()
        tr_loader = tqdm(train_loader, total=total_step // args.batch_size, desc='Train', mininterval=1)
        for feat, target, mask in tr_loader:
            reset_hidden_states(model, mask)  # 종료된 session은 hidden_state를 초기화합니다. 아래 메서드에서 확인해주세요.

            input_ohe = to_categorical(feat, num_classes=args.num_items)
            input_ohe = np.expand_dims(input_ohe, axis=1)
            target_ohe = to_categorical(target, num_classes=args.num_items)

            result = model.train_on_batch(input_ohe, target_ohe)
            tr_loader.set_postfix(train_loss=result[0], accuracy = result[1])

        val_recall, val_mrr = get_metrics(args.val, model, args, args.k)  # valid set에 대해 검증합니다.

        print(f"\t - Recall@{args.k} epoch {epoch}: {val_recall:3f}")
        print(f"\t - MRR@{args.k}    epoch {epoch}: {val_mrr:3f}\n")


def reset_hidden_states(model, mask):
    gru_layer = model.get_layer(name='GRU')  # model에서 gru layer를 가져옵니다.
    hidden_states = gru_layer.states[0].numpy()  # gru_layer의 parameter를 가져옵니다.
    for elt in mask:  # mask된 인덱스 즉, 종료된 세션의 인덱스를 돌면서
        hidden_states[elt, :] = 0  # parameter를 초기화 합니다.
    gru_layer.reset_states(states=hidden_states)


def get_metrics(data, model, args, k: int):  # valid셋과 test셋을 평가하는 코드입니다. 
                                             # train과 거의 같지만 mrr, recall을 구하는 라인이 있습니다.
    dataset = SessionDataset(data)
    loader = SessionDataLoader(dataset, batch_size=args.batch_size)
    recall_list, mrr_list = [], []

    total_step = len(data) - data['UserId'].nunique()
    for inputs, label, mask in tqdm(loader, total=total_step // args.batch_size, desc='Evaluation', mininterval=1):
        reset_hidden_states(model, mask)
        input_ohe = to_categorical(inputs, num_classes=args.num_items)
        input_ohe = np.expand_dims(input_ohe, axis=1)

        pred = model.predict(input_ohe, batch_size=args.batch_size)
        pred_arg = tf.argsort(pred, direction='DESCENDING')  # softmax 값이 큰 순서대로 sorting 합니다.

        length = len(inputs)
        recall_list.extend([recall_k(pred_arg[i], label[i], k) for i in range(length)])
        mrr_list.extend([mrr_k(pred_arg[i], label[i], k) for i in range(length)])

    recall, mrr = np.mean(recall_list), np.mean(mrr_list)
    return recall, mrr

# %%
train_model(model, args)
# Out:
# Train:  97%|█████████▋| 6127/6290 [01:36<00:02, 63.19it/s, accuracy=0.0234, train_loss=6.54]
# Evaluation:  26%|██▌       | 101/385 [01:16<03:33,  1.33it/s]
# Train:   0%|          | 0/6290 [00:00<?, ?it/s, accuracy=0.0625, train_loss=5.86]
# 	 - Recall@20 epoch 1: 0.213954
# 	 - MRR@20    epoch 1: 0.055594
# Train:  97%|█████████▋| 6127/6290 [01:37<00:02, 63.12it/s, accuracy=0.0547, train_loss=6.12]
# Evaluation:  26%|██▌       | 101/385 [01:15<03:30,  1.35it/s]
# Train:   0%|          | 0/6290 [00:00<?, ?it/s, accuracy=0.0781, train_loss=5.3]
# 	 - Recall@20 epoch 2: 0.283803
# 	 - MRR@20    epoch 2: 0.079105
# Train:  97%|█████████▋| 6127/6290 [01:35<00:02, 63.94it/s, accuracy=0.0234, train_loss=5.93]
# Evaluation:  26%|██▌       | 101/385 [01:12<03:24,  1.39it/s]
# 	 - Recall@20 epoch 3: 0.311262
# 	 - MRR@20    epoch 3: 0.091160

# %%
test
# Out:
#         UserId  ItemId  Rating                Time  item_idx
# 5130        36    2671       5 2000-12-29 03:35:55      1205
# 5163        36    2250       4 2000-12-29 03:35:55      2467
# 5313        36    2023       4 2000-12-29 03:35:55       495
# 5088        36    1270       5 2000-12-29 03:36:22         1
# 5250        36    3301       4 2000-12-29 03:36:47       525
# ...        ...     ...     ...                 ...       ...
# 992358    5996    3835       3 2002-04-29 20:46:24      1185
# 992279    5996    2422       3 2002-04-29 20:47:05      1052
# 992702    5996     168       3 2002-09-03 13:12:26      1064
# 992459    5996     339       4 2002-10-07 13:24:39       735
# 992387    5996    3882       3 2002-11-04 16:55:55      2019
#
# [139362 rows x 5 columns]

# %%
def test_model(model, args, test):
    test_recall, test_mrr = get_metrics(test, model, args, 20)
    print(f"\t - Recall@{args.k}: {test_recall:3f}")
    print(f"\t - MRR@{args.k}: {test_mrr:3f}\n")

test_model(model, args, test)
# Out:
# Evaluation:  72%|███████▏  | 778/1086 [09:41<03:50,  1.34it/s]
# 	 - Recall@20: 0.261498
# 	 - MRR@20: 0.072377

# %% [markdown]
# # 모델 개선 - epoch 올리기

# %%
args = Args(tr, val, test, batch_size=128, hsz=50, drop_rate=0.1, lr=0.001, epochs=10, k=20)
train_model(model, args)
# Out:
# Train:  97%|█████████▋| 6127/6290 [01:36<00:02, 63.30it/s, accuracy=0.0391, train_loss=5.87]
# Evaluation:  26%|██▌       | 101/385 [01:12<03:23,  1.40it/s]
# Train:   0%|          | 0/6290 [00:00<?, ?it/s, accuracy=0.0703, train_loss=5.17]
# 	 - Recall@20 epoch 1: 0.325186
# 	 - MRR@20    epoch 1: 0.097467
# Train:  97%|█████████▋| 6127/6290 [01:37<00:02, 62.94it/s, accuracy=0.0469, train_loss=5.81]
# Evaluation:  26%|██▌       | 101/385 [01:12<03:24,  1.39it/s]
# Train:   0%|          | 0/6290 [00:00<?, ?it/s, accuracy=0.0938, train_loss=5.24]
# 	 - Recall@20 epoch 2: 0.330600
# 	 - MRR@20    epoch 2: 0.101621
# Train:  97%|█████████▋| 6127/6290 [01:36<00:02, 63.23it/s, accuracy=0.0312, train_loss=5.81]
# Evaluation:  26%|██▌       | 101/385 [01:11<03:20,  1.42it/s]
# Train:   0%|          | 0/6290 [00:00<?, ?it/s, accuracy=0.102, train_loss=5.29]
# 	 - Recall@20 epoch 3: 0.334623
# 	 - MRR@20    epoch 3: 0.104604
# Train:  97%|█████████▋| 6127/6290 [01:38<00:02, 62.40it/s, accuracy=0.0391, train_loss=5.78]
# Evaluation:  26%|██▌       | 101/385 [01:11<03:20,  1.42it/s]
# Train:   0%|          | 0/6290 [00:00<?, ?it/s, accuracy=0.0625, train_loss=5.22]
# 	 - Recall@20 epoch 4: 0.339109
# 	 - MRR@20    epoch 4: 0.106166
# Train:  97%|█████████▋| 6127/6290 [01:38<00:02, 62.41it/s, accuracy=0.0469, train_loss=5.73]
# Evaluation:  26%|██▌       | 101/385 [01:11<03:20,  1.41it/s]
# Train:   0%|          | 0/6290 [00:00<?, ?it/s, accuracy=0.117, train_loss=5.18]
# 	 - Recall@20 epoch 5: 0.342358
# 	 - MRR@20    epoch 5: 0.107362
# Train:  97%|█████████▋| 6127/6290 [01:35<00:02, 63.91it/s, accuracy=0.0391, train_loss=5.78]
# Evaluation:  26%|██▌       | 101/385 [01:11<03:22,  1.40it/s]
# Train:   0%|          | 0/6290 [00:00<?, ?it/s, accuracy=0.0859, train_loss=5.07]
# 	 - Recall@20 epoch 6: 0.341043
# 	 - MRR@20    epoch 6: 0.108102
# Train:  97%|█████████▋| 6127/6290 [01:35<00:02, 63.89it/s, accuracy=0.0469, train_loss=5.72]
# Evaluation:  26%|██▌       | 101/385 [01:11<03:21,  1.41it/s]
# Train:   0%|          | 0/6290 [00:00<?, ?it/s, accuracy=0.109, train_loss=5.09]
# 	 - Recall@20 epoch 7: 0.342358
# 	 - MRR@20    epoch 7: 0.108611
# Train:  97%|█████████▋| 6127/6290 [01:36<00:02, 63.29it/s, accuracy=0.0469, train_loss=5.7]
# Evaluation:  26%|██▌       | 101/385 [01:11<03:20,  1.42it/s]
# Train:   0%|          | 0/6290 [00:00<?, ?it/s, accuracy=0.102, train_loss=5.1]
# 	 - Recall@20 epoch 8: 0.343209
# 	 - MRR@20    epoch 8: 0.109580
# Train:  97%|█████████▋| 6127/6290 [01:36<00:02, 63.70it/s, accuracy=0.0391, train_loss=5.65]
# Evaluation:  26%|██▌       | 101/385 [01:11<03:20,  1.41it/s]
# Train:   0%|          | 0/6290 [00:00<?, ?it/s, accuracy=0.0938, train_loss=5.21]
# 	 - Recall@20 epoch 9: 0.344291
# 	 - MRR@20    epoch 9: 0.109877
# Train:  97%|█████████▋| 6127/6290 [01:36<00:02, 63.24it/s, accuracy=0.0391, train_loss=5.64]
# Evaluation:  26%|██▌       | 101/385 [01:11<03:22,  1.40it/s]
# 	 - Recall@20 epoch 10: 0.342590
# 	 - MRR@20    epoch 10: 0.111264

# %%
test_model(model, args, test)
# Out:
# Evaluation:  72%|███████▏  | 778/1086 [09:29<03:45,  1.37it/s]
# 	 - Recall@20: 0.283188
# 	 - MRR@20: 0.086039

# %% [markdown]
# # 모델 개선 - train, val, test셋 다르게 분리

# %%
tr, test = split_by_date(data, n_days=30)
tr, val = split_by_date(tr, n_days=30)

# %%
train_model(model, args)
# Out:
# Train:  97%|█████████▋| 6913/7135 [01:52<00:03, 62.37it/s, accuracy=0.00781, train_loss=6.38]

# %%
test_model(model, args, test)

# %% [markdown]
# - 모델1 -> 모델2
#     epoch을 3에서 10으로 늘렸떠니 recall값이 증가하는걸 볼 수 있다.
# - 모델2 -> 모델3
#     왜 index 에러가나는지 모르겠다
