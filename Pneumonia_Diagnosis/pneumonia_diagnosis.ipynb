# %% [markdown]
# # Setup

# %%
import os, re
import random, math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE
# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*'
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

# 프로젝트를 진행할 때 아래 두 변수를 변경해보세요
BATCH_SIZE = 16
EPOCHS = 25

print(ROOT_PATH)
# Out:
# /aiffel/aiffel

# %% [markdown]
# # Data

# %%
train_filenames = tf.io.gfile.glob(TRAIN_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %% [markdown]
# ### train, validation set 나누기

# %%
# train 데이터와 validation 데이터를 모두 filenames에 담습니다
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나눕니다
train_size = math.floor(len(filenames)*0.8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

print("train_file개수 :",len(train_filenames))
print("val_file개수 :",len(val_filenames))
# Out:
# train_file개수 : 4185
# val_file개수 : 1047

# %% [markdown]
# * math.floor
#     - Math.floor( 45.95); //  45
#     - Math.floor(-45.05); // -46

# %%
# 정상 이미지와 폐렴 이미지를 구분해야 하는데
# 다행히도 파일 경로에 힌트가 있어요
print(f'Normal image path\n{filenames[0]}')
print(f'Pneumonia image path\n{filenames[4000]}')
# Out:
# Normal image path
# /aiffel/aiffel/chest_xray/data/train/PNEUMONIA/person1395_bacteria_3544.jpeg
# Pneumonia image path
# /aiffel/aiffel/chest_xray/data/train/NORMAL/IM-0582-0001.jpeg

# %% [markdown]
# - normal 데이터는 NORMAL 폴더에 / pneumonia 데이터는 PNEUMONIA폴더에 담겨있음

# %% [markdown]
# ### NORMAL과 PNEUMONIA데이터의 수는?

# %%
# 이제 파일 경로에 NORMAL이 있는지 확인하면 정상 이미지를 셀 수 있습니다.
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")

# 파일 경로에 PNEUMONIA이 있는지 확인하면 폐렴 이미지도 셀 수 있습니다.
COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1076
# Pneumonia images count in training set: 3109

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
# 파일 경로의 끝에서 두번째 부분을 확인하면 양성과 음성을 구분할 수 있습니다
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

# %%
# 이미지를 알맞은 형식으로 바꿉니다.
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어옵니다.
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  True

# %%
test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# # 데이터 시각화

# %%
# 이미지 배치를 입력하면 여러장의 이미지를 보여줍니다.
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(5,math.ceil(BATCH_SIZE/5),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")


image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# ### Batch Normalization - Normalization + Dropout(=regularization)

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# # 데이터 Imbalance 전처리

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for NORMAL: {:.2f}'.format(weight_for_0))
print('Weight for PNEUMONIA: {:.2f}'.format(weight_for_1))
# Out:
# Weight for NORMAL: 1.91
# Weight for PNEUMONIA: 0.68

# %% [markdown]
# # 모델 훈련

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 261/261 [==============================] - 66s 152ms/step - loss: 0.5299 - accuracy: 0.7299 - precision: 0.9119 - recall: 0.6991 - val_loss: 0.7785 - val_accuracy: 0.7548 - val_precision: 0.7548 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 38s 145ms/step - loss: 0.2474 - accuracy: 0.9119 - precision: 0.9723 - recall: 0.9066 - val_loss: 1.1531 - val_accuracy: 0.7558 - val_precision: 0.7558 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 38s 146ms/step - loss: 0.1935 - accuracy: 0.9255 - precision: 0.9743 - recall: 0.9238 - val_loss: 0.2110 - val_accuracy: 0.9106 - val_precision: 0.8944 - val_recall: 1.0000
# Epoch 4/25
# 261/261 [==============================] - 38s 147ms/step - loss: 0.1877 - accuracy: 0.9290 - precision: 0.9823 - recall: 0.9219 - val_loss: 0.0978 - val_accuracy: 0.9625 - val_precision: 0.9857 - val_recall: 0.9645
# Epoch 5/25
# 261/261 [==============================] - 38s 145ms/step - loss: 0.1569 - accuracy: 0.9416 - precision: 0.9816 - recall: 0.9385 - val_loss: 0.1602 - val_accuracy: 0.9442 - val_precision: 0.9986 - val_recall: 0.92776 - recall: 0.9
# Epoch 6/25
# 261/261 [==============================] - 38s 145ms/step - loss: 0.1415 - accuracy: 0.9458 - precision: 0.9842 - recall: 0.9421 - val_loss: 0.0959 - val_accuracy: 0.9692 - val_precision: 0.9748 - val_recall: 0.9848
# Epoch 7/25
# 261/261 [==============================] - 38s 144ms/step - loss: 0.1390 - accuracy: 0.9481 - precision: 0.9834 - recall: 0.9460 - val_loss: 0.7031 - val_accuracy: 0.7740 - val_precision: 1.0000 - val_recall: 0.7014
# Epoch 8/25
# 261/261 [==============================] - 38s 145ms/step - loss: 0.1454 - accuracy: 0.9420 - precision: 0.9886 - recall: 0.9338 - val_loss: 0.1374 - val_accuracy: 0.9490 - val_precision: 0.9973 - val_recall: 0.9352
# Epoch 9/25
# 261/261 [==============================] - 38s 146ms/step - loss: 0.1401 - accuracy: 0.9471 - precision: 0.9854 - recall: 0.9426 - val_loss: 0.2241 - val_accuracy: 0.9125 - val_precision: 1.0000 - val_recall: 0.8842
# Epoch 10/25
# 261/261 [==============================] - 38s 145ms/step - loss: 0.1096 - accuracy: 0.9578 - precision: 0.9888 - recall: 0.9533 - val_loss: 0.1087 - val_accuracy: 0.9529 - val_precision: 0.9933 - val_recall: 0.9440
# Epoch 11/25
# 261/261 [==============================] - 38s 145ms/step - loss: 0.1052 - accuracy: 0.9618 - precision: 0.9902 - recall: 0.9575 - val_loss: 0.1748 - val_accuracy: 0.9356 - val_precision: 1.0000 - val_recall: 0.9149ion: 0.991 - ETA: 5s - loss: 0.103
# Epoch 12/25
# 261/261 [==============================] - 38s 146ms/step - loss: 0.1306 - accuracy: 0.9530 - precision: 0.9860 - recall: 0.9499 - val_loss: 0.1479 - val_accuracy: 0.9490 - val_precision: 0.9378 - val_recall: 0.9987
# Epoch 13/25
# 261/261 [==============================] - 38s 146ms/step - loss: 0.0974 - accuracy: 0.9699 - precision: 0.9904 - recall: 0.9683 - val_loss: 0.1598 - val_accuracy: 0.9433 - val_precision: 0.9312 - val_recall: 0.9987
# Epoch 14/25
# 261/261 [==============================] - 38s 146ms/step - loss: 0.1086 - accuracy: 0.9639 - precision: 0.9858 - recall: 0.9645 - val_loss: 0.1062 - val_accuracy: 0.9606 - val_precision: 0.9617 - val_recall: 0.9873
# Epoch 15/25
# 261/261 [==============================] - 38s 145ms/step - loss: 0.1099 - accuracy: 0.9569 - precision: 0.9884 - recall: 0.9538 - val_loss: 0.0994 - val_accuracy: 0.9683 - val_precision: 0.9833 - val_recall: 0.9746
# Epoch 16/25
# 261/261 [==============================] - 38s 145ms/step - loss: 0.1120 - accuracy: 0.9591 - precision: 0.9813 - recall: 0.9612 - val_loss: 0.2410 - val_accuracy: 0.9173 - val_precision: 1.0000 - val_recall: 0.8904
# Epoch 17/25
# 261/261 [==============================] - 38s 146ms/step - loss: 0.0824 - accuracy: 0.9690 - precision: 0.9941 - recall: 0.9638 - val_loss: 0.2629 - val_accuracy: 0.9087 - val_precision: 1.0000 - val_recall: 0.8791
# Epoch 18/25
# 261/261 [==============================] - 39s 148ms/step - loss: 0.0934 - accuracy: 0.9684 - precision: 0.9921 - recall: 0.9647 - val_loss: 0.2906 - val_accuracy: 0.9125 - val_precision: 1.0000 - val_recall: 0.8844
# Epoch 19/25
# 261/261 [==============================] - 38s 145ms/step - loss: 0.0814 - accuracy: 0.9721 - precision: 0.9947 - recall: 0.9672 - val_loss: 0.3024 - val_accuracy: 0.9019 - val_precision: 0.9985 - val_recall: 0.8715
# Epoch 20/25
# 261/261 [==============================] - 38s 146ms/step - loss: 0.0950 - accuracy: 0.9614 - precision: 0.9895 - recall: 0.9579 - val_loss: 0.1613 - val_accuracy: 0.9260 - val_precision: 0.9986 - val_recall: 0.9032
# Epoch 21/25
# 261/261 [==============================] - 38s 146ms/step - loss: 0.0810 - accuracy: 0.9715 - precision: 0.9934 - recall: 0.9677 - val_loss: 0.0899 - val_accuracy: 0.9721 - val_precision: 0.9679 - val_recall: 0.9962
# Epoch 22/25
# 261/261 [==============================] - 38s 146ms/step - loss: 0.0535 - accuracy: 0.9813 - precision: 0.9948 - recall: 0.9797 - val_loss: 0.5622 - val_accuracy: 0.8183 - val_precision: 1.0000 - val_recall: 0.7595
# Epoch 23/25
# 261/261 [==============================] - 38s 146ms/step - loss: 0.0729 - accuracy: 0.9750 - precision: 0.9926 - recall: 0.9738 - val_loss: 0.0774 - val_accuracy: 0.9731 - val_precision: 0.9749 - val_recall: 0.9898
# Epoch 24/25
# 261/261 [==============================] - 38s 145ms/step - loss: 0.0551 - accuracy: 0.9817 - precision: 0.9962 - recall: 0.9791 - val_loss: 0.1139 - val_accuracy: 0.9558 - val_precision: 0.9987 - val_recall: 0.9428
# Epoch 25/25
# 261/261 [==============================] - 38s 145ms/step - loss: 0.0831 - accuracy: 0.9726 - precision: 0.9928 - recall: 0.9693 - val_loss: 0.1280 - val_accuracy: 0.9510 - val_precision: 0.9973 - val_recall: 0.9377

# %% [markdown]
# ## 결과 확인

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 39/39 [==============================] - 4s 89ms/step - loss: 0.6791 - accuracy: 0.8141 - precision: 0.7854 - recall: 0.9667
# Loss: 0.6791428923606873,
# Accuracy: 0.8141025900840759,
# Precision: 0.7854166626930237,
# Recall: 0.9666666388511658

# %% [markdown]
# ## Normalization + Dropout(=regularization) 결과
# - Accuracy : 81%
# - Recall : 96%

# %% [markdown]
# ------------------

# %% [markdown]
# #  ablation study

# %% [markdown]
# ## augmentation  기법 적용 (사진 좌우 반전)

# %% [markdown]
# # Setup

# %%
import os, re
import random, math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE
# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*'
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

# 프로젝트를 진행할 때 아래 두 변수를 변경해보세요
BATCH_SIZE = 16
EPOCHS = 25

print(ROOT_PATH)
# Out:
# /aiffel/aiffel

# %% [markdown]
# # Data

# %%
train_filenames = tf.io.gfile.glob(TRAIN_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %% [markdown]
# ### train, validation set 나누기

# %%
# train 데이터와 validation 데이터를 모두 filenames에 담습니다
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나눕니다
train_size = math.floor(len(filenames)*0.8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

print("train_file개수 :",len(train_filenames))
print("val_file개수 :",len(val_filenames))
# Out:
# train_file개수 : 4185
# val_file개수 : 1047

# %% [markdown]
# * math.floor
#     - Math.floor( 45.95); //  45
#     - Math.floor(-45.05); // -46

# %%
# 정상 이미지와 폐렴 이미지를 구분해야 하는데
# 다행히도 파일 경로에 힌트가 있어요
print(f'Normal image path\n{filenames[0]}')
print(f'Pneumonia image path\n{filenames[4000]}')
# Out:
# Normal image path
# /aiffel/aiffel/chest_xray/data/train/PNEUMONIA/person1395_bacteria_3544.jpeg
# Pneumonia image path
# /aiffel/aiffel/chest_xray/data/train/NORMAL/IM-0582-0001.jpeg

# %% [markdown]
# - normal 데이터는 NORMAL 폴더에 / pneumonia 데이터는 PNEUMONIA폴더에 담겨있음

# %% [markdown]
# ### NORMAL과 PNEUMONIA데이터의 수는?

# %%
# 이제 파일 경로에 NORMAL이 있는지 확인하면 정상 이미지를 셀 수 있습니다.
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")

# 파일 경로에 PNEUMONIA이 있는지 확인하면 폐렴 이미지도 셀 수 있습니다.
COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1076
# Pneumonia images count in training set: 3109

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
# 파일 경로의 끝에서 두번째 부분을 확인하면 양성과 음성을 구분할 수 있습니다
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

# %%
# 이미지를 알맞은 형식으로 바꿉니다.
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어옵니다.
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  True

# %%
test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %%
def augment(image,label):
    image = tf.image.random_flip_left_right(image)  # 랜덤하게 좌우를 반전합니다.
    return image,label

def prepare_for_training(ds, shuffle_buffer_size=1000):
    # augment 적용 부분이 배치처리 함수에 추가되었습니다.
    ds = ds.map(
            augment,       # augment 함수 적용
            num_parallel_calls=2
        )
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# # 데이터 시각화

# %%
# 이미지 배치를 입력하면 여러장의 이미지를 보여줍니다.
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(5,math.ceil(BATCH_SIZE/5),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")


image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# ### Batch Normalization - Normalization + Dropout(=regularization) + augmentation

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# # 데이터 Imbalance 전처리

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for NORMAL: {:.2f}'.format(weight_for_0))
print('Weight for PNEUMONIA: {:.2f}'.format(weight_for_1))
# Out:
# Weight for NORMAL: 1.94
# Weight for PNEUMONIA: 0.67

# %% [markdown]
# # 모델 훈련

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 261/261 [==============================] - 47s 151ms/step - loss: 0.5485 - accuracy: 0.7307 - precision: 0.9000 - recall: 0.7008 - val_loss: 0.7083 - val_accuracy: 0.7385 - val_precision: 0.7385 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 38s 147ms/step - loss: 0.2406 - accuracy: 0.9089 - precision: 0.9671 - recall: 0.9081 - val_loss: 1.1995 - val_accuracy: 0.7385 - val_precision: 0.7385 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 38s 146ms/step - loss: 0.2439 - accuracy: 0.9129 - precision: 0.9615 - recall: 0.9167 - val_loss: 0.2677 - val_accuracy: 0.8981 - val_precision: 0.9985 - val_recall: 0.8635
# Epoch 4/25
# 261/261 [==============================] - 38s 147ms/step - loss: 0.1983 - accuracy: 0.9291 - precision: 0.9788 - recall: 0.9238 - val_loss: 0.0995 - val_accuracy: 0.9663 - val_precision: 0.9842 - val_recall: 0.9701
# Epoch 5/25
# 261/261 [==============================] - 39s 148ms/step - loss: 0.1787 - accuracy: 0.9340 - precision: 0.9740 - recall: 0.9361 - val_loss: 0.1880 - val_accuracy: 0.9231 - val_precision: 0.9065 - val_recall: 0.9987
# Epoch 6/25
# 261/261 [==============================] - 38s 148ms/step - loss: 0.1694 - accuracy: 0.9314 - precision: 0.9761 - recall: 0.9297 - val_loss: 0.1861 - val_accuracy: 0.9298 - val_precision: 1.0000 - val_recall: 0.9051
# Epoch 7/25
# 261/261 [==============================] - 39s 151ms/step - loss: 0.1681 - accuracy: 0.9328 - precision: 0.9809 - recall: 0.9270 - val_loss: 0.1148 - val_accuracy: 0.9538 - val_precision: 0.9839 - val_recall: 0.9531
# Epoch 8/25
# 261/261 [==============================] - 39s 148ms/step - loss: 0.1385 - accuracy: 0.9542 - precision: 0.9842 - recall: 0.9530 - val_loss: 0.2257 - val_accuracy: 0.9221 - val_precision: 0.9985 - val_recall: 0.8958
# Epoch 9/25
# 261/261 [==============================] - 39s 148ms/step - loss: 0.1652 - accuracy: 0.9371 - precision: 0.9768 - recall: 0.9359 - val_loss: 0.0872 - val_accuracy: 0.9615 - val_precision: 0.9880 - val_recall: 0.9597
# Epoch 10/25
# 261/261 [==============================] - 39s 148ms/step - loss: 0.1251 - accuracy: 0.9566 - precision: 0.9860 - recall: 0.9546 - val_loss: 0.1752 - val_accuracy: 0.9250 - val_precision: 0.9986 - val_recall: 0.8999
# Epoch 11/25
# 261/261 [==============================] - 39s 148ms/step - loss: 0.1482 - accuracy: 0.9450 - precision: 0.9815 - recall: 0.9423 - val_loss: 0.1394 - val_accuracy: 0.9385 - val_precision: 0.9972 - val_recall: 0.9194
# Epoch 12/25
# 261/261 [==============================] - 38s 147ms/step - loss: 0.1314 - accuracy: 0.9534 - precision: 0.9901 - recall: 0.9462 - val_loss: 0.0862 - val_accuracy: 0.9654 - val_precision: 0.9946 - val_recall: 0.9584
# Epoch 13/25
# 261/261 [==============================] - 39s 149ms/step - loss: 0.1455 - accuracy: 0.9424 - precision: 0.9856 - recall: 0.9364 - val_loss: 0.1571 - val_accuracy: 0.9337 - val_precision: 0.9986 - val_recall: 0.9116
# Epoch 14/25
# 261/261 [==============================] - 38s 147ms/step - loss: 0.1234 - accuracy: 0.9562 - precision: 0.9887 - recall: 0.9505 - val_loss: 0.1388 - val_accuracy: 0.9471 - val_precision: 0.9384 - val_recall: 0.9935
# Epoch 15/25
# 261/261 [==============================] - 38s 147ms/step - loss: 0.1237 - accuracy: 0.9496 - precision: 0.9823 - recall: 0.9483 - val_loss: 0.2033 - val_accuracy: 0.9260 - val_precision: 1.0000 - val_recall: 0.8997
# Epoch 16/25
# 261/261 [==============================] - 39s 148ms/step - loss: 0.1051 - accuracy: 0.9596 - precision: 0.9903 - recall: 0.9552 - val_loss: 0.1362 - val_accuracy: 0.9394 - val_precision: 1.0000 - val_recall: 0.9179
# Epoch 17/25
# 261/261 [==============================] - 38s 147ms/step - loss: 0.1404 - accuracy: 0.9440 - precision: 0.9841 - recall: 0.9395 - val_loss: 0.0771 - val_accuracy: 0.9702 - val_precision: 0.9817 - val_recall: 0.9779
# Epoch 18/25
# 261/261 [==============================] - 38s 147ms/step - loss: 0.1022 - accuracy: 0.9616 - precision: 0.9914 - recall: 0.9565 - val_loss: 0.2169 - val_accuracy: 0.9635 - val_precision: 0.9778 - val_recall: 0.9727
# Epoch 19/25
# 261/261 [==============================] - 38s 147ms/step - loss: 0.1102 - accuracy: 0.9586 - precision: 0.9923 - recall: 0.9520 - val_loss: 0.0659 - val_accuracy: 0.9702 - val_precision: 0.9986 - val_recall: 0.9610
# Epoch 20/25
# 261/261 [==============================] - 39s 148ms/step - loss: 0.0805 - accuracy: 0.9675 - precision: 0.9926 - recall: 0.9634 - val_loss: 0.0894 - val_accuracy: 0.9625 - val_precision: 0.9959 - val_recall: 0.9532
# Epoch 21/25
# 261/261 [==============================] - 39s 148ms/step - loss: 0.0978 - accuracy: 0.9628 - precision: 0.9918 - recall: 0.9585 - val_loss: 0.2116 - val_accuracy: 0.9154 - val_precision: 1.0000 - val_recall: 0.8854
# Epoch 22/25
# 261/261 [==============================] - 39s 148ms/step - loss: 0.1003 - accuracy: 0.9605 - precision: 0.9905 - recall: 0.9550 - val_loss: 0.0848 - val_accuracy: 0.9654 - val_precision: 0.9946 - val_recall: 0.9585
# Epoch 23/25
# 261/261 [==============================] - 39s 148ms/step - loss: 0.0981 - accuracy: 0.9594 - precision: 0.9887 - recall: 0.9566 - val_loss: 0.7292 - val_accuracy: 0.8779 - val_precision: 0.8591 - val_recall: 0.9987
# Epoch 24/25
# 261/261 [==============================] - 38s 147ms/step - loss: 0.1022 - accuracy: 0.9632 - precision: 0.9925 - recall: 0.9573 - val_loss: 0.0996 - val_accuracy: 0.9577 - val_precision: 0.9972 - val_recall: 0.9452
# Epoch 25/25
# 261/261 [==============================] - 38s 147ms/step - loss: 0.0870 - accuracy: 0.9672 - precision: 0.9943 - recall: 0.9615 - val_loss: 0.1129 - val_accuracy: 0.9481 - val_precision: 0.9972 - val_recall: 0.9326

# %% [markdown]
# ## 결과 확인

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 39/39 [==============================] - 4s 88ms/step - loss: 0.6053 - accuracy: 0.8590 - precision: 0.8356 - recall: 0.9641
# Loss: 0.6053093671798706,
# Accuracy: 0.8589743375778198,
# Precision: 0.8355555534362793,
# Recall: 0.964102566242218

# %% [markdown]
# ## Augmentation 결과
# - Accuracy : 85%
# - Recall : 96%
